# %% [markdown]
# # MONAI Label Radiology App - OHIF Segmentation
#
# ***The OHIF + MONAI Label integration with segmentation***
#
# In this notebook, we show end-to-end setup of the web-based OHIF viewer and MONAI Label plugin.
#
# <p align = "center"><img src="../figures/monailabel_radiology_spleen_segmentation_OHIF/ohif0.png" alt="drawing" width="900"/></p>
#
# ## 1. Prepare Required Packages

# %% [markdown]
# ## Setup environment
#
# ### Prerequisites
# - **Install MONAI Label** weekly preview release:
# - **First time of installation** might takes around 5-10 mins.

# %%
# !pip install monailabel

# %%
# !pip install "pydicom<3.0" "pydicom-seg==0.4.1" --force-reinstall

# %%
# !pip install pandas
# Out:
# /bin/bash: /app/miniconda/24.11.1/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Requirement already satisfied: pandas in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.23.2 in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import os, subprocess, pandas as pd

# --- Detect your username automatically ---
username = os.getenv("USER") or os.getenv("USERNAME") or "qmedasia"

print(f"Detected username: {username}")

# --- Get all GPU processes from nvidia-smi ---
cmd = "nvidia-smi --query-compute-apps=pid,process_name,used_gpu_memory --format=csv,noheader,nounits"
output = subprocess.check_output(cmd, shell=True).decode().strip().split("\n")

processes = []
for line in output:
    parts = [p.strip() for p in line.split(",")]
    if len(parts) == 3:
        pid, name, mem = parts
        # Only include processes owned by the user
        try:
            proc_user = subprocess.check_output(f"ps -o user= -p {pid}", shell=True).decode().strip()
            if proc_user == username:
                processes.append({"PID": pid, "Process": name, "GPU Memory (MB)": int(mem)})
        except:
            pass

df = pd.DataFrame(processes)

if df.empty:
    print("No GPU processes belonging to you.")
else:
    print("\nKilling your GPU processes...")
    display(df)

    # Kill them all
    for pid in df["PID"]:
        try:
            subprocess.call(f"kill -9 {pid}", shell=True)
            print(f"Killed PID {pid}")
        except Exception as e:
            print(f"Error killing {pid}: {e}")

    print("\nDone. Run nvidia-smi to verify.")
# Out:
# Detected username: qmedasia
# No GPU processes belonging to you.

# %% [markdown]
# ### 1.1 Download Radiology app
# Choose "radiology" as the app

# %%
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'
os.environ['PYTHONUTF8'] = '1'

# !monailabel apps --download --name radiology --output apps
# Out:
# /bin/bash: /app/miniconda/24.11.1/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /app/miniconda/24.11.1/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Using PYTHONPATH=/scr/user/qmedasia:
#
# Directory already exists: /scr/user/qmedasia/.bootcamp/monai/nvidia_monai_worksop_1/lab_1_MONAI_Label_with_OHIF_Viewer/apps/radiology

# %% [markdown]
# ## 2. Access Orthanc DICOM Server
#
# OHIF works well with the web-based Orthanc DICOM Server. Orthanc provides a simple, and powerful standalone DICOM server. It is designed to improve the DICOM flows in hospitals and to support research about the automated analysis of medical images. For more details on Orthanc, please refer to the [Orthanc](https://www.orthanc-server.com/index.php) page.
#
# The official [download page](https://www.orthanc-server.com/download.php) provides detailed steps for installing Orthanc.

# %%
# %%capture captured_cell
# %%bash
ifconfig enp226s0 | grep -Po '(?<=inet )(\d{1,3}\.){3}\d{1,3}'

# %% [markdown]
# ## Orthanc Dicom Server Access in OOD
#
# In current session, the Orthanc DICOM server is hosted in OOD HPC resource, where the link to access is:

# %% [markdown]
# ## Orthanc Dicom Server Access in OOD
#
# In current session, the Orthanc DICOM server is hosted in OOD HPC resource, where the link to access is:
#
# **http://10.11.132.43:8042/**
#
# - username: orthanc
# - password: orthanc
#
# The index page of Orthanc DICOM Web page:
#
# <p align = "center"><img src="../figures/monailabel_radiology_spleen_segmentation_OHIF/ohif1.png/" alt="drawing" width="900"/></p>

# %% [markdown]
# ## 3. Prepare Dicom Sample data
#
# ### 3.1 Download Spleen CT DICOM Data
# Download MSD Spleen dataset as the sample dataset using monailabel API. The task is the volumetric (3D) segmentation of the spleen from CT image. The segmentation of the spleen is formulated as the voxel-wise 2-class classification. Each voxel is predicted as either foreground (spleen) or background. The dataset is from the 2018 MICCAI challenge.

# %%
import os
import gdown
import zipfile

# Google Drive file ID
file_id = '1w1HmGT7IrgcbwfmxCLwDxLZ4_bNPMvst'

root_dir = os.getcwd()

compressed_file = os.path.join(root_dir, "dicom_output.zip")
data_root_dir = os.path.join(root_dir, "dicom_output")
final_data_dir = os.path.join(data_root_dir, "dicom_output")

# Check if the final data directory already exists
if not os.path.exists(final_data_dir):
    print("Downloading...")
    gdown.download(f'https://drive.google.com/uc?id={file_id}', compressed_file, quiet=False)
    print("Download complete.")

    print("Unzipping...")
    try:
        # Extract the contents to the 'Task09_Spleen' folder, not the nested one
        with zipfile.ZipFile(compressed_file, 'r') as zip_ref:
            zip_ref.extractall(data_root_dir)
        print("Unzipping complete.")
    except zipfile.BadZipFile:
        print("Error: The downloaded file is corrupted or not a valid zip file.")
        if os.path.exists(compressed_file):
            os.remove(compressed_file)
else:
    print("Data directory already exists. Skipping download and extraction.")
# Out:
# Data directory already exists. Skipping download and extraction.

# %% [markdown]
# ### 3.2 Upload to Orthanc
#
# - Click `Upload` on the top right corner of Orthanc index page.
#
# <p align = "center"><img src="../figures/monailabel_radiology_spleen_segmentation_OHIF/ohif2.png/" alt="drawing" width="900"/></p>
#
# - Click `Select files to upload` and select **all** DICOM files of each subject.
# - Click `Start the upload` to upload to Orthanc server.
# - Users can check the uploaded DICOM file for each subject by clicking `All `studies` on the index page.
#
# <p align = "center"><img src="../figures/monailabel_radiology_spleen_segmentation_OHIF/ohif3.png" alt="drawing" width="900"/></p>

# %% [markdown]
# ## 4. Start MONAI Label Server
#
# The command will start MONAI Label server with all available models. If the user wants to start with a specific model, set the model name in the **--conf models** argument.
#
# Such as
#
# ```bash
# monailabel start_server --app <path to pathology app> --studies <Orthanc server URL> --conf models <segmentation>
# ```
# In the command, ```--app``` specifies the pathology app path, ```--studies``` specifies the datastore URL.
#
# In this OOD session, change the studies argument as: **http://orthanc:orthanc@10.11.132.43/dicom-web**
#
# **Note:**
# 1. *If you are running a MONAI Label server in this notebook and plan to close the notebook, ensure that you terminate the kernel first. Failing to do so might result in an issue where the port remains occupied from the previous session when you try to restart the server later. To prevent this, always terminate the kernel before closing the notebook.*
# 2. *The server start up might takes up to 5 minutes.*
# 3. *By default is monailabel server is up with port 8000, if port 8000 is occupied by another application, users can specify the port number by `--port <port #>` in monailabel start_server command.*

# %%
# %%capture captured_cell
# %%bash
ifconfig enp226s0 | grep -Po '(?<=inet )(\d{1,3}\.){3}\d{1,3}'

# %%
## Port num preparation

myip = captured_cell.stdout[:-1]
myip

username = !whoami
username = username[-1]

if username != 'qmedasia':
    monailblportnum = 8800+int(username[-1][-2:])
else:
    monailblportnum = 8889

# %%
print('Access MONAI Label after running the cell BELOW first: http://%s:%d/ohif' % (myip, monailblportnum))
# Out:
# Access MONAI Label after running the cell BELOW first: http://10.11.132.43:8889/ohif

# %%
# !monailabel start_server --app apps/radiology \
    --studies http://orthanc:orthanc@$myip:8042/dicom-web \
    --conf models segmentation \
    --conf scribbles true
# Out:
# /bin/bash: /app/miniconda/24.11.1/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /app/miniconda/24.11.1/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Using PYTHONPATH=/scr/user/qmedasia:
#
# [2025-11-13 21:35:19,455] [2347129] [MainThread] [INFO] (__main__:285) - USING:: version = False
# [2025-11-13 21:35:19,455] [2347129] [MainThread] [INFO] (__main__:285) - USING:: app = /scr/user/qmedasia/.bootcamp/monai/nvidia_monai_worksop_1/lab_1_MONAI_Label_with_OHIF_Viewer/apps/radiology
# [2025-11-13 21:35:19,456] [2347129] [MainThread] [INFO] (__main__:285) - USING:: studies = http://orthanc:orthanc@10.11.132.43:8042/dicom-web
# [2025-11-13 21:35:19,456] [2347129] [MainThread] [INFO] (__main__:285) - USING:: verbose = INFO
# [2025-11-13 21:35:19,456] [2347129] [MainThread] [INFO] (__main__:285) - USING:: conf = [['models', 'segmentation'], ['scribbles', 'true']]
# [2025-11-13 21:35:19,456] [2347129] [MainThread] [INFO] (__main__:285) - USING:: host = 0.0.0.0
# [2025-11-13 21:35:19,456] [2347129] [MainThread] [INFO] (__main__:285) - USING:: port = 8000
# [2025-11-13 21:35:19,456] [2347129] [MainThread] [INFO] (__main__:285) - USING:: uvicorn_app = monailabel.app:app
# [2025-11-13 21:35:19,456] [2347129] [MainThread] [INFO] (__main__:285) - USING:: ssl_keyfile = None
# [2025-11-13 21:35:19,456] [2347129] [MainThread] [INFO] (__main__:285) - USING:: ssl_certfile = None
# [2025-11-13 21:35:19,456] [2347129] [MainThread] [INFO] (__main__:285) - USING:: ssl_keyfile_password = None
# [2025-11-13 21:35:19,456] [2347129] [MainThread] [INFO] (__main__:285) - USING:: ssl_ca_certs = None
# [2025-11-13 21:35:19,456] [2347129] [MainThread] [INFO] (__main__:285) - USING:: workers = None
# [2025-11-13 21:35:19,456] [2347129] [MainThread] [INFO] (__main__:285) - USING:: limit_concurrency = None
# [2025-11-13 21:35:19,456] [2347129] [MainThread] [INFO] (__main__:285) - USING:: access_log = False
# [2025-11-13 21:35:19,456] [2347129] [MainThread] [INFO] (__main__:285) - USING:: root_path =
# [2025-11-13 21:35:19,456] [2347129] [MainThread] [INFO] (__main__:285) - USING:: log_level = info
# [2025-11-13 21:35:19,456] [2347129] [MainThread] [INFO] (__main__:285) - USING:: log_config = None
# [2025-11-13 21:35:19,456] [2347129] [MainThread] [INFO] (__main__:285) - USING:: dryrun = False
# [2025-11-13 21:35:19,456] [2347129] [MainThread] [INFO] (__main__:285) - USING:: action = start_server
# [2025-11-13 21:35:19,456] [2347129] [MainThread] [INFO] (__main__:296) -
# Allow Origins: ['*']
# [2025-11-13 21:35:20,221] [2347129] [MainThread] [INFO] (uvicorn.error:84) - Started server process [2347129]
# [2025-11-13 21:35:20,221] [2347129] [MainThread] [INFO] (uvicorn.error:48) - Waiting for application startup.
# App Init...
# [2025-11-13 21:35:20,221] [2347129] [MainThread] [INFO] (monailabel.interfaces.utils.app:37) - Initializing App from: /scr/user/qmedasia/.bootcamp/monai/nvidia_monai_worksop_1/lab_1_MONAI_Label_with_OHIF_Viewer/apps/radiology; studies: http://orthanc:orthanc@10.11.132.43:8042/dicom-web; conf: {'models': 'segmentation', 'scribbles': 'true'}
# [2025-11-13 21:35:20,306] [2347129] [MainThread] [INFO] (monailabel.utils.others.class_utils:57) - Subclass for MONAILabelApp Found: <class 'main.MyApp'>
# [2025-11-13 21:35:20,320] [2347129] [MainThread] [INFO] (monailabel.utils.others.class_utils:57) - Subclass for TaskConfig Found: <class 'lib.configs.segmentation.Segmentation'>
# [2025-11-13 21:35:20,322] [2347129] [MainThread] [INFO] (monailabel.utils.others.class_utils:57) - Subclass for TaskConfig Found: <class 'lib.configs.localization_spine.LocalizationSpine'>
# [2025-11-13 21:35:20,324] [2347129] [MainThread] [INFO] (monailabel.utils.others.class_utils:57) - Subclass for TaskConfig Found: <class 'lib.configs.segmentation_vertebra.SegmentationVertebra'>
# [2025-11-13 21:35:20,327] [2347129] [MainThread] [INFO] (monailabel.utils.others.class_utils:57) - Subclass for TaskConfig Found: <class 'lib.configs.deepgrow_2d.Deepgrow2D'>
# [2025-11-13 21:35:20,329] [2347129] [MainThread] [INFO] (monailabel.utils.others.class_utils:57) - Subclass for TaskConfig Found: <class 'lib.configs.localization_vertebra.LocalizationVertebra'>
# [2025-11-13 21:35:20,336] [2347129] [MainThread] [INFO] (monailabel.utils.others.class_utils:57) - Subclass for TaskConfig Found: <class 'lib.configs.segmentation_spleen.SegmentationSpleen'>
# [2025-11-13 21:35:20,338] [2347129] [MainThread] [INFO] (monailabel.utils.others.class_utils:57) - Subclass for TaskConfig Found: <class 'lib.configs.sw_fastedit.SWFastEditConfig'>
# [2025-11-13 21:35:20,340] [2347129] [MainThread] [INFO] (monailabel.utils.others.class_utils:57) - Subclass for TaskConfig Found: <class 'lib.configs.deepedit.DeepEdit'>
# [2025-11-13 21:35:20,342] [2347129] [MainThread] [INFO] (monailabel.utils.others.class_utils:57) - Subclass for TaskConfig Found: <class 'lib.configs.deepgrow_3d.Deepgrow3D'>
# [2025-11-13 21:35:20,343] [2347129] [MainThread] [INFO] (main:95) - +++ Adding Model: segmentation => lib.configs.segmentation.Segmentation
# [2025-11-13 21:35:20,457] [2347129] [MainThread] [INFO] (main:98) - +++ Using Models: ['segmentation']
# [2025-11-13 21:35:20,459] [2347129] [MainThread] [INFO] (monailabel.interfaces.app:135) - Init Datastore for: http://orthanc:orthanc@10.11.132.43:8042/dicom-web
# [2025-11-13 21:35:20,461] [2347129] [MainThread] [INFO] (monailabel.interfaces.app:156) - Using DICOM WEB: http://orthanc:orthanc@10.11.132.43:8042/dicom-web
# [2025-11-13 21:35:20,464] [2347129] [MainThread] [INFO] (monailabel.datastore.dicom:62) - DICOMWeb Datastore (cache) Path: /home/user/qmedasia/.cache/monailabel/dicom/ee9125346fb8d7b842fc9f9bf3185642; FetchByFrame: False
# [2025-11-13 21:35:20,465] [2347129] [MainThread] [INFO] (monailabel.datastore.dicom:63) - DICOMWeb Convert To Nifti: True
# [2025-11-13 21:35:20,467] [2347129] [MainThread] [INFO] (monailabel.datastore.local:130) - Auto Reload: True; Extensions: ('*.nii.gz', '*.nii')
# [2025-11-13 21:35:20,474] [2347129] [MainThread] [INFO] (monailabel.datastore.local:577) - Invalidate count: 0
# [2025-11-13 21:35:20,476] [2347129] [MainThread] [INFO] (monailabel.datastore.local:151) - Start observing external modifications on datastore (AUTO RELOAD)
# [2025-11-13 21:35:20,631] [2347129] [MainThread] [INFO] (main:129) - +++ Adding Inferer:: segmentation => <lib.infers.segmentation.Segmentation object at 0x7fe39a6df4d0>
# [2025-11-13 21:35:20,818] [2347129] [MainThread] [INFO] (monailabel.sam2.infer:65) - Image Cache Initialized: /home/user/qmedasia/.cache/monailabel/sam2
# [2025-11-13 21:35:20,821] [timeloop] [INFO] Starting Timeloop..
# [2025-11-13 21:35:20,821] [2347129] [MainThread] [INFO] (timeloop:60) - Starting Timeloop..
# [2025-11-13 21:35:20,823] [timeloop] [INFO] Registered job <function ImageCache.monitor.<locals>.run_scheduler at 0x7fe394ad9120>
# [2025-11-13 21:35:20,823] [2347129] [MainThread] [INFO] (timeloop:42) - Registered job <function ImageCache.monitor.<locals>.run_scheduler at 0x7fe394ad9120>
# [2025-11-13 21:35:20,825] [timeloop] [INFO] Timeloop now started. Jobs will run based on the interval set
# [2025-11-13 21:35:20,825] [2347129] [MainThread] [INFO] (timeloop:63) - Timeloop now started. Jobs will run based on the interval set
#
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
# [2025-11-13 21:35:20,828] [2347129] [MainThread] [INFO] (main:206) - {'segmentation': <lib.infers.segmentation.Segmentation object at 0x7fe39a6df4d0>, 'Histogram+GraphCut': <monailabel.scribbles.infer.HistogramBasedGraphCut object at 0x7fe39a6cc050>, 'GMM+GraphCut': <monailabel.scribbles.infer.GMMBasedGraphCut object at 0x7fe3967cc110>, 'sam_2d': <monailabel.sam2.infer.Sam2InferTask object at 0x7fe39a792350>, 'sam_3d': <monailabel.sam2.infer.Sam2InferTask object at 0x7fe399f851d0>}
# [2025-11-13 21:35:20,831] [2347129] [MainThread] [INFO] (main:221) - +++ Adding Trainer:: segmentation => <lib.trainers.segmentation.Segmentation object at 0x7fe39683c410>
# [2025-11-13 21:35:20,832] [2347129] [MainThread] [INFO] (monailabel.utils.sessions:51) - Session Path: /home/user/qmedasia/.cache/monailabel/sessions
# [2025-11-13 21:35:20,834] [2347129] [MainThread] [INFO] (monailabel.utils.sessions:52) - Session Expiry (max): 3600
# [2025-11-13 21:35:20,836] [2347129] [MainThread] [INFO] (monailabel.interfaces.app:469) - App Init - completed
# [2025-11-13 21:35:20,838] [timeloop] [INFO] Starting Timeloop..
# [2025-11-13 21:35:20,838] [timeloop] [INFO] Starting Timeloop..
# [2025-11-13 21:35:20,838] [2347129] [MainThread] [INFO] (timeloop:60) - Starting Timeloop..
# [2025-11-13 21:35:20,840] [timeloop] [INFO] Registered job <function MONAILabelApp.on_init_complete.<locals>.run_scheduler at 0x7fe394ad93a0>
# [2025-11-13 21:35:20,840] [timeloop] [INFO] Registered job <function MONAILabelApp.on_init_complete.<locals>.run_scheduler at 0x7fe394ad93a0>
# [2025-11-13 21:35:20,840] [2347129] [MainThread] [INFO] (timeloop:42) - Registered job <function MONAILabelApp.on_init_complete.<locals>.run_scheduler at 0x7fe394ad93a0>
# [2025-11-13 21:35:20,841] [timeloop] [INFO] Timeloop now started. Jobs will run based on the interval set
# [2025-11-13 21:35:20,841] [timeloop] [INFO] Timeloop now started. Jobs will run based on the interval set
# [2025-11-13 21:35:20,841] [2347129] [MainThread] [INFO] (timeloop:63) - Timeloop now started. Jobs will run based on the interval set
# [2025-11-13 21:35:20,843] [2347129] [MainThread] [INFO] (uvicorn.error:62) - Application startup complete.
# [2025-11-13 21:35:20,844] [2347129] [MainThread] [INFO] (uvicorn.error:216) - Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages/IPython/utils/_process_posix.py:130, in ProcessHandler.system(self, cmd)
#     127 while True:
#     128     # res is the index of the pattern that caused the match, so we
#     129     # know whether we've finished (if we matched EOF) or not
# --> 130     res_idx = child.expect_list(patterns, self.read_timeout)
#     131     print(child.before[out_size:].decode(enc, 'replace'), end='')
#
# File /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages/pexpect/spawnbase.py:383, in SpawnBase.expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
#     382 else:
# --> 383     return exp.expect_loop(timeout)
#
# File /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages/pexpect/expect.py:169, in Expecter.expect_loop(self, timeout)
#     168 # Still have time left, so read more data
# --> 169 incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#     170 if self.spawn.delayafterread is not None:
#
# File /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages/pexpect/pty_spawn.py:500, in spawn.read_nonblocking(self, size, timeout)
#     497 # Because of the select(0) check above, we know that no data
#     498 # is available right now. But if a non-zero timeout is given
#     499 # (possibly timeout=None), we call select() with a timeout.
# --> 500 if (timeout != 0) and select(timeout):
#     501     return super(spawn, self).read_nonblocking(size)
#
# File /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages/pexpect/pty_spawn.py:450, in spawn.read_nonblocking.<locals>.select(timeout)
#     449 def select(timeout):
# --> 450     return select_ignore_interrupts([self.child_fd], [], [], timeout)[0]
#
# File /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages/pexpect/utils.py:143, in select_ignore_interrupts(iwtd, owtd, ewtd, timeout)
#     142 try:
# --> 143     return select.select(iwtd, owtd, ewtd, timeout)
#     144 except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 get_ipython().system('monailabel start_server --app apps/radiology      --studies http://orthanc:orthanc@$myip:8042/dicom-web      --conf models segmentation      --conf scribbles true')
#
# File /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages/ipykernel/zmqshell.py:657, in ZMQInteractiveShell.system_piped(self, cmd)
#     655         self.user_ns["_exit_code"] = system(cmd)
#     656 else:
# --> 657     self.user_ns["_exit_code"] = system(self.var_expand(cmd, depth=1))
#
# File /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages/IPython/utils/_process_posix.py:154, in ProcessHandler.system(self, cmd)
#     151         pass
#     152     finally:
#     153         # Ensure the subprocess really is terminated
# --> 154         child.terminate(force=True)
#     155 # add isalive check, to ensure exitstatus is set:
#     156 child.isalive()
#
# File /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages/pexpect/pty_spawn.py:646, in spawn.terminate(self, force)
#     644     return True
#     645 self.kill(signal.SIGCONT)
# --> 646 time.sleep(self.delayafterterminate)
#     647 if not self.isalive():
#     648     return True
#
# KeyboardInterrupt:

# %% [markdown]
# ## 5. Start OHIF Viewer
#
# Since the DICOM server is hosted in OOD, we need to access through OOD IP address:
#
# **http://10.11.132.42:8000/ohif/** (OOD)
#
# Open the OHIF viewer, users can see the subject list as below:
#
# <p align = "center"><img src="../figures/monailabel_radiology_spleen_segmentation_OHIF/ohif4.png/" alt="drawing" width="900"/></p>

# %% [markdown]
# ## 6. Auto Segmentation with OHIF
#
# Below is a step-by-step tutorial on using OHIF for auto-spleen segmentation. Pre-trained model is provided by the MONAI Label.
#
# ### 6.1 MONAI Label Plugin
#
# - MONAI Label plugin is already build-in. Click the subject to annotate, in the labeling page, click `MONAI Label` button in the top-right corner.
#
# <p align = "center"><img src="../figures/monailabel_radiology_spleen_segmentation_OHIF/ohif5.png/" alt="drawing" width="900"/></p>
#
# ### 6.2 Run Auto Segmentation
#
# - MONAI Label has loaded the pre-trained weights, click **Run** button in the right MONAI Label plugin panel.
#
# - Note: the pre-trained models will be downloaded when starting MONAI Label server in the "**model**" folder. For instance, in this use case, the downloaded pre-trained model is saved at "**apps/radiology/model/pretrained_segmentation.pt**".
#
# Users can monitor the logs in the MONAI Label server terminal.
#
# The auto segmentation results can show up as below:
#
# <p align = "center"><img src="../figures/monailabel_radiology_spleen_segmentation_OHIF/ohif6.png/" alt="drawing" width="900"/></p>
