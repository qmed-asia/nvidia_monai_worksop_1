# %% [markdown]
# # 3D Brain Tumor Segmentation with Swin UNETR (BraTS 21 Challenge)
#
#
# This tutorial uses the [Swin UNETR](https://arxiv.org/pdf/2201.01266.pdf) [1,2] model for the task of brain tumor segmentation using the [BraTS 21](http://braintumorsegmentation.org/) challenge dataset [3,4,5,6]. Swin UNETR ranked among top-performing models in the BraTS 21 validation phase. The architecture of Swin UNETR is demonstrated below
#
# ![swin_brats](../figures/swin_brats21.png)
#
# The following features are included in this tutorial:
# 1. Transforms for dictionary format data.
# 1. Define a new transform according to MONAI transform API.
# 1. Load Nifti image with metadata, load a list of images and stack them.
# 1. Randomly rotate across each axes for data augmentation.
# 1. Randomly adjust the intensity for data augmentation.
# 1. Cache IO and transforms to accelerate training and validation.
# 1. Swin UNETR model, Dice loss function, Mean Dice metric for brain tumor segmentation task.
#
#
# ### Tumor Characteristics
#
# The sub-regions considered for evaluation in the BraTS 21 challenge are the "enhancing tumor" (ET), the "tumor core" (TC), and the "whole tumor" (WT). The ET is described by areas that show hyper-intensity in T1Gd when compared to T1, but also when compared to “healthy” white matter in T1Gd. The TC describes the bulk of the tumor, which is what is typically resected. The TC entails the ET, as well as the necrotic (NCR) parts of the tumor. The appearance of NCR is typically hypo-intense in T1-Gd when compared to T1. The WT describes the complete extent of the disease, as it entails the TC and the peritumoral edematous/invaded tissue (ED), which is typically depicted by the hyper-intense signal in FLAIR [[BraTS 21]](http://braintumorsegmentation.org/).
#
# The provided segmentation labels have values of 1 for NCR, 2 for ED, 4 for ET, and 0 for everything else.
#
# ![image](../figures/fig_brats21.png)
#
# Figure from [Baid et al.](https://arxiv.org/pdf/2107.02314v1.pdf) [3]
#
#
#
# ## References
#
#
# If you find this tutorial helpful, please consider citing [1] and [2]:
#
# [1]: Hatamizadeh, A., Nath, V., Tang, Y., Yang, D., Roth, H. and Xu, D., 2022. Swin UNETR: Swin Transformers for Semantic Segmentation of Brain Tumors in MRI Images. arXiv preprint arXiv:2201.01266.
#
# [2]: Tang, Y., Yang, D., Li, W., Roth, H.R., Landman, B., Xu, D., Nath, V. and Hatamizadeh, A., 2022. Self-supervised pre-training of swin transformers for 3d medical image analysis. In Proceedings of the IEEE/CVF Conference on Computer Vision and Pattern Recognition (pp. 20730-20740).
#
#
# ### BraTS Dataset References
#
# [3] U.Baid, et al., The RSNA-ASNR-MICCAI BraTS 2021 Benchmark on Brain Tumor Segmentation and Radiogenomic Classification, arXiv:2107.02314, 2021.
#
# [4] B. H. Menze, A. Jakab, S. Bauer, J. Kalpathy-Cramer, K. Farahani, J. Kirby, et al. "The Multimodal Brain Tumor Image Segmentation Benchmark (BRATS)", IEEE Transactions on Medical Imaging 34(10), 1993-2024 (2015) DOI: 10.1109/TMI.2014.2377694
#
# [5] S. Bakas, H. Akbari, A. Sotiras, M. Bilello, M. Rozycki, J.S. Kirby, et al., "Advancing The Cancer Genome Atlas glioma MRI collections with expert segmentation labels and radiomic features", Nature Scientific Data, 4:170117 (2017) DOI: 10.1038/sdata.2017.117
#
# [6] S. Bakas, H. Akbari, A. Sotiras, M. Bilello, M. Rozycki, J. Kirby, et al., "Segmentation Labels and Radiomic Features for the Pre-operative Scans of the TCGA-GBM collection", The Cancer Imaging Archive, 2017. DOI: 10.7937/K9/TCIA.2017.KLXWJJ1Q

# %% [markdown]
# ## Swin UNETR Model
#
# The inputs to [Swin UNETR](https://arxiv.org/pdf/2201.01266.pdf) are 3D multi-modal MRI images with 4 channels.
# The patch partition block creates non-overlapping patches of the input data and projects them into embedding tokens with a resolution of 128x128x128.
# The projected tokens are then encoded by using a 3D [Swin Transformer](https://openaccess.thecvf.com/content/ICCV2021/papers/Liu_Swin_Transformer_Hierarchical_Vision_Transformer_Using_Shifted_Windows_ICCV_2021_paper.pdf) in which the self-attention is computed within local windows.
# The interaction between different windows is obtained by using 3D window shifting as illustrated below.
#
# ![image](../figures/shift_patch.png)
#
# The transformer-based encoder is connected to a CNN-decoder via skip connection at multiple resolutions.
# The segmentation output consists of 3 output channels corresponding to ET, WT, and TC sub-regions and is computed by using a 1x1x1 convolutional layer followed by Sigmoid activation function.

# %% [markdown]
# ## Setup environment

# %%
# !pip install pandas

# %%
import os, subprocess, pandas as pd

# --- Detect your username automatically ---
username = os.getenv("USER") or os.getenv("USERNAME") or "qmedasia"

print(f"Detected username: {username}")

# --- Get all GPU processes from nvidia-smi ---
cmd = "nvidia-smi --query-compute-apps=pid,process_name,used_gpu_memory --format=csv,noheader,nounits"
output = subprocess.check_output(cmd, shell=True).decode().strip().split("\n")

processes = []
for line in output:
    parts = [p.strip() for p in line.split(",")]
    if len(parts) == 3:
        pid, name, mem = parts
        # Only include processes owned by the user
        try:
            proc_user = subprocess.check_output(f"ps -o user= -p {pid}", shell=True).decode().strip()
            if proc_user == username:
                processes.append({"PID": pid, "Process": name, "GPU Memory (MB)": int(mem)})
        except:
            pass

df = pd.DataFrame(processes)

if df.empty:
    print("No GPU processes belonging to you.")
else:
    print("\nKilling your GPU processes...")
    display(df)

    # Kill them all
    for pid in df["PID"]:
        try:
            subprocess.call(f"kill -9 {pid}", shell=True)
            print(f"Killed PID {pid}")
        except Exception as e:
            print(f"Error killing {pid}: {e}")

    print("\nDone. Run nvidia-smi to verify.")
# Out:
# Detected username: qmedasia
#
# Killing your GPU processes...
#        PID                                        Process  GPU Memory (MB)
# 0  1294410  /scr/user/qmedasia/monai_py311/bin/python3.11             6860
# Killed PID 1294410
#
# Done. Run nvidia-smi to verify.

# %%
# Set the environment variable to allow duplicate OpenMP libraries
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'

# %%
#!python -c "import monai" || pip install -q "monai-weekly[gdown, nibabel, tqdm, ignite]"
# !pip install -q "monai-weekly[gdown, nibabel, tqdm, ignite]
# !python -c "import matplotlib" || pip install -q matplotlib
# !pip install gdown
# !pip install nibabel
# %matplotlib inline
# Out:
# /bin/bash: /app/miniconda/24.11.1/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `"'
# /bin/bash: -c: line 2: syntax error: unexpected end of file
# /bin/bash: /app/miniconda/24.11.1/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: /app/miniconda/24.11.1/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Requirement already satisfied: gdown in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from gdown) (4.14.2)
# Requirement already satisfied: filelock in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from gdown) (3.19.1)
# Requirement already satisfied: requests[socks] in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from gdown) (2.32.5)
# Requirement already satisfied: tqdm in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from requests[socks]->gdown) (2025.10.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from requests[socks]->gdown) (1.7.1)
# /bin/bash: /app/miniconda/24.11.1/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Requirement already satisfied: nibabel in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (5.3.2)
# Requirement already satisfied: importlib-resources>=5.12 in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from nibabel) (6.5.2)
# Requirement already satisfied: numpy>=1.22 in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from nibabel) (1.26.4)
# Requirement already satisfied: packaging>=20 in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from nibabel) (25.0)
# Requirement already satisfied: typing-extensions>=4.6 in /scr/user/qmedasia/monai_py311/lib/python3.11/site-packages (from nibabel) (4.15.0)

# %% [markdown]
# ## Setup imports

# %%
import os
import json
import shutil
import tempfile
import time

import matplotlib.pyplot as plt
import numpy as np
import nibabel as nib

from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai import transforms
from monai.transforms import (
    AsDiscrete,
    Activations,
)

from monai.config import print_config
from monai.metrics import DiceMetric
from monai.utils.enums import MetricReduction
from monai.networks.nets import SwinUNETR
from monai import data
from monai.data import decollate_batch
from functools import partial

from torch.utils.tensorboard import SummaryWriter

import torch


print_config()
# Out:
# MONAI version: 1.5.1
# Numpy version: 1.26.4
# Pytorch version: 2.6.0+cu124
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: 9c6d819f97e37f36c72f3bdfad676b455bd2fa0d
# MONAI __file__: /scr/user/<username>/monai_py311/lib/python3.11/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.4.11
# ITK version: 5.4.4
# Nibabel version: 5.3.2
# scikit-image version: 0.25.2
# scipy version: 1.16.3
# Pillow version: 11.3.0
# Tensorboard version: 2.20.0
# gdown version: 5.2.0
# TorchVision version: 0.21.0+cu124
# tqdm version: 4.67.1
# lmdb version: 1.7.5
# psutil version: 7.1.3
# pandas version: 2.3.3
# einops version: 0.8.1
# transformers version: NOT INSTALLED or UNKNOWN VERSION.
# mlflow version: 3.6.0
# pynrrd version: 1.1.3
# clearml version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %% [markdown]
# ## Download Dataset from GDrive

# %%
import os
import gdown
import zipfile

# Google Drive file ID
file_id = '1FVgmSx_b7HjJF3_3mN71WJRPoqJiiY69'

root_dir = os.getcwd()
print(f"Using current directory as root: {root_dir}")

compressed_file = os.path.join(root_dir, "TrainingData.zip")
data_root_dir = os.path.join(root_dir, "TrainingData")
final_data_dir = os.path.join(data_root_dir, "TrainingData")
print(f"Using current dataset directory: {final_data_dir}")

# Check if the final data directory already exists
if not os.path.exists(final_data_dir):
    print("Downloading...")
    gdown.download(f'https://drive.google.com/uc?id={file_id}', compressed_file, quiet=False)
    print("Download complete.")

    print("Unzipping...")
    try:
        # Extract the contents to the 'Task09_Spleen' folder, not the nested one
        with zipfile.ZipFile(compressed_file, 'r') as zip_ref:
            zip_ref.extractall(data_root_dir)
        print("Unzipping complete.")
    except zipfile.BadZipFile:
        print("Error: The downloaded file is corrupted or not a valid zip file.")
        if os.path.exists(compressed_file):
            os.remove(compressed_file)
else:
    print("Data directory already exists. Skipping download and extraction.")
# Out:
# Using current directory as root: /scr/user/qmedasia/.bootcamp/monai/nvidia_monai_worksop_1/lab_4_Brain_Tumor_Segmentation_3D
# Using current dataset directory: /scr/user/qmedasia/.bootcamp/monai/nvidia_monai_worksop_1/lab_4_Brain_Tumor_Segmentation_3D/TrainingData/TrainingData
# Downloading...
# Downloading...
# From (original): https://drive.google.com/uc?id=1FVgmSx_b7HjJF3_3mN71WJRPoqJiiY69
# From (redirected): https://drive.google.com/uc?id=1FVgmSx_b7HjJF3_3mN71WJRPoqJiiY69&confirm=t&uuid=13c79b28-b177-4ab0-b379-2f9ebeb5649d
# To: /scr/user/qmedasia/.bootcamp/monai/nvidia_monai_worksop_1/lab_4_Brain_Tumor_Segmentation_3D/TrainingData.zip
# 100%|██████████| 2.12G/2.12G [00:38<00:00, 55.5MB/s]
# Download complete.
# Unzipping...
# Unzipping complete.

# %% [markdown]
# ## Setup average meter, fold reader, checkpoint saver

# %%
class AverageMeter(object):
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = np.where(self.count > 0, self.sum / self.count, self.sum)


def datafold_read(datalist, basedir, fold=0, key="training"):
    with open(datalist) as f:
        json_data = json.load(f)

    json_data = json_data[key]

    for d in json_data:
        for k in d:
            if isinstance(d[k], list):
                d[k] = [os.path.join(basedir, iv) for iv in d[k]]
            elif isinstance(d[k], str):
                d[k] = os.path.join(basedir, d[k]) if len(d[k]) > 0 else d[k]

    tr = []
    val = []
    for d in json_data:
        if "fold" in d and d["fold"] == fold:
            val.append(d)
        else:
            tr.append(d)

    return tr, val


def save_checkpoint(model, epoch, filename="model.pt", best_acc=0, dir_add=root_dir):
    state_dict = model.state_dict()
    save_dict = {"epoch": epoch, "best_acc": best_acc, "state_dict": state_dict}
    filename = os.path.join(dir_add, filename)
    torch.save(save_dict, filename)
    print("Saving checkpoint", filename)

# %% [markdown]
# ## Setup dataloader

# %%
def get_loader(batch_size, data_dir, json_list, fold, roi):
    data_dir = data_dir
    datalist_json = json_list
    train_files, validation_files = datafold_read(datalist=datalist_json, basedir=data_dir, fold=fold)
    train_transform = transforms.Compose(
        [
            transforms.LoadImaged(keys=["image", "label"]),
            transforms.ConvertToMultiChannelBasedOnBratsClassesd(keys="label"),
            transforms.CropForegroundd(
                keys=["image", "label"],
                source_key="image",
                k_divisible=[roi[0], roi[1], roi[2]],
                allow_smaller=True,
            ),
            transforms.RandSpatialCropd(
                keys=["image", "label"],
                roi_size=[roi[0], roi[1], roi[2]],
                random_size=False,
            ),
            transforms.RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),
            transforms.RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=1),
            transforms.RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=2),
            transforms.NormalizeIntensityd(keys="image", nonzero=True, channel_wise=True),
            transforms.RandScaleIntensityd(keys="image", factors=0.1, prob=1.0),
            transforms.RandShiftIntensityd(keys="image", offsets=0.1, prob=1.0),
        ]
    )
    val_transform = transforms.Compose(
        [
            transforms.LoadImaged(keys=["image", "label"]),
            transforms.ConvertToMultiChannelBasedOnBratsClassesd(keys="label"),
            transforms.NormalizeIntensityd(keys="image", nonzero=True, channel_wise=True),
        ]
    )

    train_ds = data.Dataset(data=train_files, transform=train_transform)

    train_loader = data.DataLoader(
        train_ds,
        batch_size=batch_size,
        shuffle=True,
        num_workers=8,
        pin_memory=True,
    )
    val_ds = data.Dataset(data=validation_files, transform=val_transform)
    val_loader = data.DataLoader(
        val_ds,
        batch_size=1,
        shuffle=False,
        num_workers=8,
        pin_memory=True,
    )

    return train_loader, val_loader

# %% [markdown]
# ## Set dataset root directory and hyper-parameters
#
# The following hyper-parameters are set for the purpose of this tutorial. However, additional changes, as described below, maybe beneficial.
#
# If GPU memory is not sufficient, reduce sw_batch_size to 2 or batch_size to 1.
#
# Decrease val_every (validation frequency) to 1 for obtaining more accurate checkpoints.
#
# <a id="hyperparameters"></a>
#
# ### Hyperparameters:
#
# - **roi**: Larger ROI gives more context but slows training heavily.
# - **batch_size**: Bigger batch stabilizes training but increases memory and can slow steps.
# - **sw_batch_size**: Larger value speeds up validation but uses more GPU memory.
# - **val_every**: Smaller interval runs validation more often and slows overall training.
# - **infer_overlap**: Higher overlap improves output smoothness but makes validation slower.
# - **fold**: Only selects data split and does not affect training speed.
# - **max_epochs**: More epochs improve learning but increase total training time.

# %%
data_dir = final_data_dir
print(f"Setting MONAI data_dir to: {data_dir}")

json_list = os.path.join(data_dir,"brats21_folds_demo.json")
print(f"JSON List Directory: {json_list}")

roi = (96, 96, 96)
batch_size = 2
sw_batch_size = 2
val_every = 2
infer_overlap = 0.25
fold = 1
max_epochs = 5

## Try for better training results (Take longer time to train)
# roi = (128, 128, 128)
# batch_size = 2
# sw_batch_size = 2
# fold = 1
# infer_overlap = 0.5
# max_epochs = 10
# val_every = 2
train_loader, val_loader = get_loader(batch_size, data_dir, json_list, fold, roi)
# Out:
# Setting MONAI data_dir to: /scr/user/qmedasia/.bootcamp/monai/nvidia_monai_worksop_1/lab_4_Brain_Tumor_Segmentation_3D/TrainingData/TrainingData
# JSON List Directory: /scr/user/qmedasia/.bootcamp/monai/nvidia_monai_worksop_1/lab_4_Brain_Tumor_Segmentation_3D/TrainingData/TrainingData/brats21_folds_demo.json

# %% [markdown]
# ## Dataset EDA (split counts)

# %%
train_files, val_files = datafold_read(datalist=json_list, basedir=data_dir, fold=fold)
train_count = len(train_files)
val_count = len(val_files)
total_cases = train_count + val_count

print(f"Fold used for validation/test: {fold}")
print(f"Training cases: {train_count}")
print(f"Validation/Test cases: {val_count}")
print(f"Total labeled cases: {total_cases}")

split_names = ["Train", f"Fold {fold}"]
split_values = [train_count, val_count]
plt.figure(figsize=(6, 4))
plt.bar(split_names, split_values, color=["#1f77b4", "#ff7f0e"])
plt.ylabel("Number of cases")
plt.title("BraTS21 split distribution (current fold)")
for idx, value in enumerate(split_values):
    plt.text(idx, value + 0.5, str(value), ha="center")
plt.tight_layout()
plt.show()
# Out:
# Fold used for validation/test: 1
# Training cases: 160
# Validation/Test cases: 40
# Total labeled cases: 200

# %% [markdown]
# ## Visualize training samples with tumor labels

# %%
num_samples_to_show = min(3, len(train_files))
if num_samples_to_show == 0:
    raise RuntimeError("No training files found. Ensure dataset download completed.")

preview_transform = transforms.Compose([
    transforms.LoadImaged(keys=["image", "label"]),
    transforms.NormalizeIntensityd(keys="image", nonzero=True, channel_wise=True),
])

sample_ds = data.Dataset(data=train_files[:num_samples_to_show], transform=preview_transform)
sample_loader = data.DataLoader(sample_ds, batch_size=1, shuffle=False)

class_map = {
    1: ("NCR/NET", "#F94144"),
    2: ("ED", "#F8961E"),
    4: ("ET", "#277DA1"),
}
from matplotlib.colors import ListedColormap, BoundaryNorm
cmap = ListedColormap(["#000000"] + [info[1] for info in class_map.values()])
bounds = [-0.5] + [i + 0.5 for i in range(len(class_map) + 1)]
norm = BoundaryNorm(bounds, cmap.N)

leg_labels = [info[0] for info in class_map.values()]

fig, axes = plt.subplots(num_samples_to_show, 3, figsize=(14, 4 * num_samples_to_show))
if num_samples_to_show == 1:
    axes = [axes]

for idx, batch in enumerate(sample_loader):
    image = batch["image"][0]
    label_vol = batch["label"][0]
    if label_vol.ndim == 4:
        label_vol = label_vol[0]
    case_id = os.path.basename(train_files[idx]["label"]).replace("_seg.nii.gz", "")
    flair_slice = image[0]
    slice_idx = flair_slice.shape[-1] // 2

    axes[idx][0].imshow(flair_slice[:, :, slice_idx], cmap="gray")
    axes[idx][0].set_title(f"{case_id} - FLAIR")
    axes[idx][0].axis("off")

    label_slice = label_vol[:, :, slice_idx]
    label_vis = np.zeros_like(label_slice, dtype=np.int8)
    for new_idx, class_id in enumerate(class_map.keys(), start=1):
        label_vis[label_slice == class_id] = new_idx

    masked_vis = np.ma.masked_where(label_vis == 0, label_vis)
    axes[idx][1].imshow(flair_slice[:, :, slice_idx], cmap="gray")
    axes[idx][1].imshow(masked_vis, cmap=cmap, norm=norm, alpha=0.6)
    axes[idx][1].set_title(f"{case_id} - overlay")
    axes[idx][1].axis("off")

    axes[idx][2].imshow(label_vis, cmap=cmap, norm=norm)
    axes[idx][2].set_title(f"{case_id} - label classes")
    axes[idx][2].axis("off")

handles = [plt.Line2D([0], [0], marker="s", color="w", label=name, markerfacecolor=color, markersize=10) for name, color in class_map.values()]
fig.legend(handles, leg_labels, loc="upper center", ncol=len(class_map), bbox_to_anchor=(0.5, 0.97))
fig.suptitle("BraTS21 training samples (axial mid-slice)", fontsize=12, y=1.02)
plt.tight_layout(rect=[0, 0, 1, 0.94])
plt.show()

# %% [markdown]
# ## Check data shape and visualize

# %%
img_add = os.path.join(data_dir, "TrainingData/BraTS2021_00579/BraTS2021_00579_flair.nii.gz")
label_add = os.path.join(data_dir, "TrainingData/BraTS2021_00579/BraTS2021_00579_seg.nii.gz")

# print(f"Image Add:{img_add}")
# print(f"Label Add:{label_add}")

img = nib.load(img_add).get_fdata()
label = nib.load(label_add).get_fdata()
print(f"image shape: {img.shape}, label shape: {label.shape}")
plt.figure("image", (18, 6))
plt.subplot(1, 2, 1)
plt.title("image")
plt.imshow(img[:, :, 78], cmap="gray")
plt.subplot(1, 2, 2)
plt.title("label")
plt.imshow(label[:, :, 78])
plt.show()
# Out:
# image shape: (240, 240, 155), label shape: (240, 240, 155)

# %% [markdown]
# ## Check VRAM Usage

# %%
# Check initial VRAM usage
initial_vram = torch.cuda.memory_allocated()
print(f"Initial VRAM usage: {initial_vram / 1024**2:.2f} MB")

# !nvidia-smi
# Out:
# Initial VRAM usage: 0.00 MB
# /bin/bash: /app/miniconda/24.11.1/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Tue Nov 11 12:49:18 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.216.03             Driver Version: 535.216.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-80GB          On  | 00000000:07:00.0 Off |                   On |
# | N/A   27C    P0              52W / 400W |     87MiB / 81920MiB |     N/A      Default |
# |                                         |                      |              Enabled |
# +-----------------------------------------+----------------------+----------------------+
# |   1  NVIDIA A100-SXM4-80GB          On  | 00000000:0F:00.0 Off |                   On |
# | N/A   41C    P0             182W / 400W |  30891MiB / 81920MiB |     N/A      Default |
# |                                         |                      |              Enabled |
# +-----------------------------------------+----------------------+----------------------+
# |   2  NVIDIA A100-SXM4-80GB          On  | 00000000:47:00.0 Off |                   On |
# | N/A   42C    P0             177W / 400W |  24319MiB / 81920MiB |     N/A      Default |
# |                                         |                      |              Enabled |
# +-----------------------------------------+----------------------+----------------------+
# |   3  NVIDIA A100-SXM4-80GB          On  | 00000000:4E:00.0 Off |                   On |
# | N/A   27C    P0              51W / 400W |     87MiB / 81920MiB |     N/A      Default |
# |                                         |                      |              Enabled |
# +-----------------------------------------+----------------------+----------------------+
# |   4  NVIDIA A100-SXM4-80GB          On  | 00000000:87:00.0 Off |                   On |
# | N/A   30C    P0              50W / 400W |     87MiB / 81920MiB |     N/A      Default |
# |                                         |                      |              Enabled |
# +-----------------------------------------+----------------------+----------------------+
# |   5  NVIDIA A100-SXM4-80GB          On  | 00000000:90:00.0 Off |                   On |
# | N/A   36C    P0              53W / 400W |     87MiB / 81920MiB |     N/A      Default |
# |                                         |                      |              Enabled |
# +-----------------------------------------+----------------------+----------------------+
# |   6  NVIDIA A100-SXM4-80GB          On  | 00000000:B7:00.0 Off |                   On |
# | N/A   35C    P0              53W / 400W |     87MiB / 81920MiB |     N/A      Default |
# |                                         |                      |              Enabled |
# +-----------------------------------------+----------------------+----------------------+
# |   7  NVIDIA A100-SXM4-80GB          On  | 00000000:BD:00.0 Off |                   On |
# | N/A   30C    P0              52W / 400W |     87MiB / 81920MiB |     N/A      Default |
# |                                         |                      |              Enabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | MIG devices:                                                                          |
# +------------------+--------------------------------+-----------+-----------------------+
# | GPU  GI  CI  MIG |                   Memory-Usage |        Vol|      Shared           |
# |      ID  ID  Dev |                     BAR1-Usage | SM     Unc| CE ENC DEC OFA JPG    |
# |                  |                                |        ECC|                       |
# |==================+================================+===========+=======================|
# |  0    2   0   0  |              37MiB / 40192MiB  | 42      0 |  3   0    2    0    0 |
# |                  |               0MiB / 65535MiB  |           |                       |
# +------------------+--------------------------------+-----------+-----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    1    2    0     147821      C   ...kun/.conda/envs/mamba310/bin/python    30796MiB |
# |    2    2    0    1283367      C   ...e/user/leokun/jupyterlab/bin/python    24224MiB |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## Create Swin UNETR model
#
# In this section, we create Swin UNETR model for the 3-class brain tumor semantic segmentation. We use a feature size of 48. We also use gradient checkpointing (use_checkpoint) for more memory-efficient training. However, use_checkpoint for faster training if enough GPU memory is available.

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"Device used: {device}")

model = SwinUNETR(
    in_channels=4,
    out_channels=3,
    feature_size=48,
    drop_rate=0.0,
    attn_drop_rate=0.0,
    dropout_path_rate=0.0,
    use_checkpoint=True,
).to(device)
# Out:
# Device used: cuda

# %% [markdown]
# ## Optimizer and loss function

# %%
torch.backends.cudnn.benchmark = True
dice_loss = DiceLoss(to_onehot_y=False, sigmoid=True)
post_sigmoid = Activations(sigmoid=True)
post_pred = AsDiscrete(argmax=False, threshold=0.5)
dice_acc = DiceMetric(include_background=True, reduction=MetricReduction.MEAN_BATCH, get_not_nans=True)
model_inferer = partial(
    sliding_window_inference,
    roi_size=[roi[0], roi[1], roi[2]],
    sw_batch_size=sw_batch_size,
    predictor=model,
    overlap=infer_overlap,
)

optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-5)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=max_epochs)

# Create a SummaryWriter instance
writer = SummaryWriter()

model_vram = torch.cuda.memory_allocated()
print(f"VRAM after model creation: {model_vram / 1024**2:.2f} MB")

# Reset max memory tracking
torch.cuda.reset_peak_memory_stats()
# Out:
# VRAM after model creation: 245.38 MB

# %% [markdown]
# ## Define Train and Validation Epoch

# %%
def train_epoch(model, loader, optimizer, epoch, loss_func, writer=None):
    model.train()
    start_time = time.time()
    run_loss = AverageMeter()
    for idx, batch_data in enumerate(loader):
        data, target = batch_data["image"].to(device), batch_data["label"].to(device)
        logits = model(data)
        loss = loss_func(logits, target)
        loss.backward()
        optimizer.step()
        run_loss.update(loss.item(), n=batch_size)
        print(
            "Epoch {}/{} {}/{}".format(epoch, max_epochs, idx, len(loader)),
            "loss: {:.4f}".format(run_loss.avg),
            "time {:.2f}s".format(time.time() - start_time),
        )
        start_time = time.time()
        
        if writer:
            writer.add_scalar("Training/Loss", run_loss.avg, epoch)
        
    return run_loss.avg


def val_epoch(
    model,
    loader,
    epoch,
    acc_func,
    model_inferer=None,
    post_sigmoid=None,
    post_pred=None,
    writer=None,
):
    model.eval()
    start_time = time.time()
    run_acc = AverageMeter()

    with torch.no_grad():
        for idx, batch_data in enumerate(loader):
            data, target = batch_data["image"].to(device), batch_data["label"].to(device)
            logits = model_inferer(data)
            val_labels_list = decollate_batch(target)
            val_outputs_list = decollate_batch(logits)
            val_output_convert = [post_pred(post_sigmoid(val_pred_tensor)) for val_pred_tensor in val_outputs_list]
            acc_func.reset()
            acc_func(y_pred=val_output_convert, y=val_labels_list)
            acc, not_nans = acc_func.aggregate()
            run_acc.update(acc.cpu().numpy(), n=not_nans.cpu().numpy())
            dice_tc = run_acc.avg[0]
            dice_wt = run_acc.avg[1]
            dice_et = run_acc.avg[2]
            val_avg_acc = np.mean(run_acc.avg)
            print(
                "Val {}/{} {}/{}".format(epoch, max_epochs, idx, len(loader)),
                ", dice_tc:",
                dice_tc,
                ", dice_wt:",
                dice_wt,
                ", dice_et:",
                dice_et,
                ", time {:.2f}s".format(time.time() - start_time),
            )
            start_time = time.time()
        
            if writer:
                writer.add_scalar("Validation/Dice_TC", dice_tc, epoch)
                writer.add_scalar("Validation/Dice_WT", dice_wt, epoch)
                writer.add_scalar("Validation/Dice_ET", dice_et, epoch)
                writer.add_scalar("Validation/Dice_Avg", val_avg_acc, epoch)

    return run_acc.avg

# %% [markdown]
# ## Define Trainer

# %%
def trainer(
    model,
    train_loader,
    val_loader,
    optimizer,
    loss_func,
    acc_func,
    scheduler,
    model_inferer=None,
    start_epoch=0,
    post_sigmoid=None,
    post_pred=None,
    writer=None,
):
    val_acc_max = 0.0
    dices_tc = []
    dices_wt = []
    dices_et = []
    dices_avg = []
    loss_epochs = []
    trains_epoch = []
    for epoch in range(start_epoch, max_epochs):
        print(time.ctime(), "Epoch:", epoch)
        epoch_time = time.time()
        train_loss = train_epoch(
            model,
            train_loader,
            optimizer,
            epoch=epoch,
            loss_func=loss_func,
            writer=writer,
        )
        print(
            "Final training  {}/{}".format(epoch, max_epochs - 1),
            "loss: {:.4f}".format(train_loss),
            "time {:.2f}s".format(time.time() - epoch_time),
        )

        if (epoch + 1) % val_every == 0 or epoch == 0:
            loss_epochs.append(train_loss)
            trains_epoch.append(int(epoch))
            epoch_time = time.time()
            val_acc = val_epoch(
                model,
                val_loader,
                epoch=epoch,
                acc_func=acc_func,
                model_inferer=model_inferer,
                post_sigmoid=post_sigmoid,
                post_pred=post_pred,
                writer=writer,
            )
            dice_tc = val_acc[0]
            dice_wt = val_acc[1]
            dice_et = val_acc[2]
            val_avg_acc = np.mean(val_acc)
            print(
                "Final validation stats {}/{}".format(epoch, max_epochs - 1),
                ", dice_tc:",
                dice_tc,
                ", dice_wt:",
                dice_wt,
                ", dice_et:",
                dice_et,
                ", Dice_Avg:",
                val_avg_acc,
                ", time {:.2f}s".format(time.time() - epoch_time),
            )
            dices_tc.append(dice_tc)
            dices_wt.append(dice_wt)
            dices_et.append(dice_et)
            dices_avg.append(val_avg_acc)
            if val_avg_acc > val_acc_max:
                print("new best ({:.6f} --> {:.6f}). ".format(val_acc_max, val_avg_acc))
                val_acc_max = val_avg_acc
                save_checkpoint(
                    model,
                    epoch,
                    best_acc=val_acc_max,
                )
            scheduler.step()
    print("Training Finished !, Best Accuracy: ", val_acc_max)
    return (
        val_acc_max,
        dices_tc,
        dices_wt,
        dices_et,
        dices_avg,
        loss_epochs,
        trains_epoch,
    )

# %% [markdown]
# ## Execute training
# - **Training** takes around 10-15 mins.
# - **Changing training parameters (epoch, learning rate)** will slow down the training process.
#
# [Click here to go to the cell for modifying hyperparameters](#hyperparameters)

# %%
start_epoch = 0

(
    val_acc_max,
    dices_tc,
    dices_wt,
    dices_et,
    dices_avg,
    loss_epochs,
    trains_epoch,
) = trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    loss_func=dice_loss,
    acc_func=dice_acc,
    scheduler=scheduler,
    model_inferer=model_inferer,
    start_epoch=start_epoch,
    post_sigmoid=post_sigmoid,
    post_pred=post_pred,
    writer=writer,
)
# Out:
# Tue Nov 11 13:22:37 2025 Epoch: 0
# Epoch 0/5 0/80 loss: 0.8587 time 3.56s
# Epoch 0/5 1/80 loss: 0.9097 time 0.64s
# Epoch 0/5 2/80 loss: 0.8467 time 0.62s
# Epoch 0/5 3/80 loss: 0.8777 time 0.68s
# Epoch 0/5 4/80 loss: 0.8798 time 0.62s
# Epoch 0/5 5/80 loss: 0.8778 time 0.62s
# Epoch 0/5 6/80 loss: 0.8852 time 0.62s
# Epoch 0/5 7/80 loss: 0.8955 time 0.62s
# Epoch 0/5 8/80 loss: 0.8898 time 0.62s
# Epoch 0/5 9/80 loss: 0.8816 time 0.62s
# Epoch 0/5 10/80 loss: 0.8699 time 0.62s
# Epoch 0/5 11/80 loss: 0.8787 time 0.62s
# Epoch 0/5 12/80 loss: 0.8738 time 0.62s
# Epoch 0/5 13/80 loss: 0.8656 time 0.62s
# Epoch 0/5 14/80 loss: 0.8642 time 0.62s
# Epoch 0/5 15/80 loss: 0.8599 time 0.62s
# Epoch 0/5 16/80 loss: 0.8553 time 0.62s
# Epoch 0/5 17/80 loss: 0.8548 time 0.62s
# Epoch 0/5 18/80 loss: 0.8590 time 0.62s
# Epoch 0/5 19/80 loss: 0.8625 time 0.62s
# Epoch 0/5 20/80 loss: 0.8657 time 0.62s
# Epoch 0/5 21/80 loss: 0.8704 time 0.62s
# Epoch 0/5 22/80 loss: 0.8658 time 0.62s
# Epoch 0/5 23/80 loss: 0.8712 time 0.62s
# Epoch 0/5 24/80 loss: 0.8706 time 0.62s
# Epoch 0/5 25/80 loss: 0.8750 time 0.63s
# Epoch 0/5 26/80 loss: 0.8793 time 0.62s
# Epoch 0/5 27/80 loss: 0.8828 time 0.62s
# Epoch 0/5 28/80 loss: 0.8835 time 0.62s
# Epoch 0/5 29/80 loss: 0.8845 time 0.62s
# Epoch 0/5 30/80 loss: 0.8882 time 0.62s
# Epoch 0/5 31/80 loss: 0.8880 time 0.62s
# Epoch 0/5 32/80 loss: 0.8864 time 0.62s
# Epoch 0/5 33/80 loss: 0.8807 time 0.62s
# Epoch 0/5 34/80 loss: 0.8796 time 0.62s
# Epoch 0/5 35/80 loss: 0.8796 time 0.62s
# Epoch 0/5 36/80 loss: 0.8820 time 0.62s
# Epoch 0/5 37/80 loss: 0.8796 time 0.62s
# Epoch 0/5 38/80 loss: 0.8763 time 0.62s
# Epoch 0/5 39/80 loss: 0.8772 time 0.62s
# Epoch 0/5 40/80 loss: 0.8772 time 0.62s
# Epoch 0/5 41/80 loss: 0.8760 time 0.62s
# Epoch 0/5 42/80 loss: 0.8762 time 0.62s
# Epoch 0/5 43/80 loss: 0.8761 time 0.62s
# Epoch 0/5 44/80 loss: 0.8788 time 0.62s
# Epoch 0/5 45/80 loss: 0.8809 time 0.62s
# Epoch 0/5 46/80 loss: 0.8828 time 0.62s
# Epoch 0/5 47/80 loss: 0.8830 time 0.62s
# Epoch 0/5 48/80 loss: 0.8840 time 0.62s
# Epoch 0/5 49/80 loss: 0.8839 time 0.62s
# Epoch 0/5 50/80 loss: 0.8850 time 0.62s
# Epoch 0/5 51/80 loss: 0.8843 time 0.62s
# Epoch 0/5 52/80 loss: 0.8855 time 0.62s
# Epoch 0/5 53/80 loss: 0.8850 time 0.62s
# Epoch 0/5 54/80 loss: 0.8835 time 0.62s
# Epoch 0/5 55/80 loss: 0.8825 time 0.62s
# Epoch 0/5 56/80 loss: 0.8834 time 0.62s
# Epoch 0/5 57/80 loss: 0.8848 time 0.62s
# Epoch 0/5 58/80 loss: 0.8859 time 0.62s
# Epoch 0/5 59/80 loss: 0.8847 time 0.62s
# Epoch 0/5 60/80 loss: 0.8825 time 0.62s
# Epoch 0/5 61/80 loss: 0.8818 time 0.62s
# Epoch 0/5 62/80 loss: 0.8797 time 0.62s
# Epoch 0/5 63/80 loss: 0.8800 time 0.62s
# Epoch 0/5 64/80 loss: 0.8783 time 0.62s
# Epoch 0/5 65/80 loss: 0.8795 time 0.62s
# Epoch 0/5 66/80 loss: 0.8791 time 0.62s
# Epoch 0/5 67/80 loss: 0.8786 time 0.62s
# Epoch 0/5 68/80 loss: 0.8788 time 0.62s
# Epoch 0/5 69/80 loss: 0.8799 time 0.62s
# Epoch 0/5 70/80 loss: 0.8775 time 0.62s
# Epoch 0/5 71/80 loss: 0.8768 time 0.62s
# Epoch 0/5 72/80 loss: 0.8758 time 0.62s
# Epoch 0/5 73/80 loss: 0.8769 time 0.62s
# Epoch 0/5 74/80 loss: 0.8765 time 0.62s
# Epoch 0/5 75/80 loss: 0.8751 time 0.62s
# Epoch 0/5 76/80 loss: 0.8754 time 0.62s
# Epoch 0/5 77/80 loss: 0.8763 time 0.62s
# Epoch 0/5 78/80 loss: 0.8775 time 0.62s
# Epoch 0/5 79/80 loss: 0.8765 time 0.62s
# Final training  0/4 loss: 0.8765 time 52.79s
# Val 0/5 0/40 , dice_tc: 0.044402864 , dice_wt: 0.33026373 , dice_et: 0.031778757 , time 3.65s
# Val 0/5 1/40 , dice_tc: 0.16484295 , dice_wt: 0.39222497 , dice_et: 0.083473645 , time 1.53s
# Val 0/5 2/40 , dice_tc: 0.14184162 , dice_wt: 0.3392364 , dice_et: 0.07602599 , time 1.53s
# Val 0/5 3/40 , dice_tc: 0.18726707 , dice_wt: 0.3562994 , dice_et: 0.11551595 , time 1.53s
# Val 0/5 4/40 , dice_tc: 0.15659502 , dice_wt: 0.29648882 , dice_et: 0.09760585 , time 1.53s
# Val 0/5 5/40 , dice_tc: 0.15956035 , dice_wt: 0.3047376 , dice_et: 0.09870243 , time 1.53s
# Val 0/5 6/40 , dice_tc: 0.13767587 , dice_wt: 0.27074912 , dice_et: 0.08529352 , time 1.53s
# Val 0/5 7/40 , dice_tc: 0.12234583 , dice_wt: 0.2642326 , dice_et: 0.076455265 , time 1.53s
# Val 0/5 8/40 , dice_tc: 0.13611986 , dice_wt: 0.27044344 , dice_et: 0.09675428 , time 1.53s
# Val 0/5 9/40 , dice_tc: 0.12506816 , dice_wt: 0.26993227 , dice_et: 0.08937012 , time 1.53s
# Val 0/5 10/40 , dice_tc: 0.12549204 , dice_wt: 0.26351073 , dice_et: 0.08231277 , time 1.53s
# Val 0/5 11/40 , dice_tc: 0.11631381 , dice_wt: 0.24601167 , dice_et: 0.07651705 , time 1.53s
# Val 0/5 12/40 , dice_tc: 0.10981376 , dice_wt: 0.23771772 , dice_et: 0.07252132 , time 1.53s
# Val 0/5 13/40 , dice_tc: 0.10512493 , dice_wt: 0.24417485 , dice_et: 0.06960913 , time 1.53s
# Val 0/5 14/40 , dice_tc: 0.10486906 , dice_wt: 0.2470435 , dice_et: 0.0713443 , time 1.53s
# Val 0/5 15/40 , dice_tc: 0.09969863 , dice_wt: 0.23941083 , dice_et: 0.068206415 , time 1.53s
# Val 0/5 16/40 , dice_tc: 0.10842967 , dice_wt: 0.24706583 , dice_et: 0.07371403 , time 1.53s
# Val 0/5 17/40 , dice_tc: 0.105311975 , dice_wt: 0.24798639 , dice_et: 0.07261495 , time 1.53s
# Val 0/5 18/40 , dice_tc: 0.10788969 , dice_wt: 0.24822526 , dice_et: 0.07284715 , time 1.53s
# Val 0/5 19/40 , dice_tc: 0.11640408 , dice_wt: 0.26237848 , dice_et: 0.07914343 , time 1.53s
# Val 0/5 20/40 , dice_tc: 0.11716644 , dice_wt: 0.2653908 , dice_et: 0.07914343 , time 1.53s
# Val 0/5 21/40 , dice_tc: 0.12001124 , dice_wt: 0.26716453 , dice_et: 0.08268976 , time 1.53s
# Val 0/5 22/40 , dice_tc: 0.123684905 , dice_wt: 0.2799862 , dice_et: 0.08537665 , time 1.53s
# Val 0/5 23/40 , dice_tc: 0.12091894 , dice_wt: 0.27468243 , dice_et: 0.08389889 , time 1.53s
# Val 0/5 24/40 , dice_tc: 0.121071175 , dice_wt: 0.28504327 , dice_et: 0.084853955 , time 1.53s
# Val 0/5 25/40 , dice_tc: 0.12539147 , dice_wt: 0.2910156 , dice_et: 0.08858558 , time 1.53s
# Val 0/5 26/40 , dice_tc: 0.123070545 , dice_wt: 0.2863997 , dice_et: 0.08690005 , time 1.53s
# Val 0/5 27/40 , dice_tc: 0.11906437 , dice_wt: 0.2771353 , dice_et: 0.084054425 , time 1.53s
# Val 0/5 28/40 , dice_tc: 0.11812579 , dice_wt: 0.28899658 , dice_et: 0.08307175 , time 1.53s
# Val 0/5 29/40 , dice_tc: 0.117902726 , dice_wt: 0.2876854 , dice_et: 0.08341467 , time 1.53s
# Val 0/5 30/40 , dice_tc: 0.12535131 , dice_wt: 0.29128104 , dice_et: 0.08732856 , time 1.53s
# Val 0/5 31/40 , dice_tc: 0.12522815 , dice_wt: 0.2933448 , dice_et: 0.08633163 , time 1.53s
# Val 0/5 32/40 , dice_tc: 0.12150584 , dice_wt: 0.2882879 , dice_et: 0.0836994 , time 1.53s
# Val 0/5 33/40 , dice_tc: 0.12101102 , dice_wt: 0.28697047 , dice_et: 0.08366622 , time 1.53s
# Val 0/5 34/40 , dice_tc: 0.12619774 , dice_wt: 0.29241747 , dice_et: 0.08585088 , time 1.53s
# Val 0/5 35/40 , dice_tc: 0.12796134 , dice_wt: 0.2997445 , dice_et: 0.088277034 , time 1.53s
# Val 0/5 36/40 , dice_tc: 0.12774986 , dice_wt: 0.3042852 , dice_et: 0.08882369 , time 1.53s
# Val 0/5 37/40 , dice_tc: 0.12590621 , dice_wt: 0.30187854 , dice_et: 0.08767528 , time 1.53s
# Val 0/5 38/40 , dice_tc: 0.122720696 , dice_wt: 0.29569653 , dice_et: 0.0853765 , time 1.53s
# Val 0/5 39/40 , dice_tc: 0.12615417 , dice_wt: 0.3007453 , dice_et: 0.08708078 , time 1.53s
# Final validation stats 0/4 , dice_tc: 0.12615417 , dice_wt: 0.3007453 , dice_et: 0.08708078 , Dice_Avg: 0.17132676 , time 63.43s
# new best (0.000000 --> 0.171327).
# Saving checkpoint /scr/user/qmedasia/.bootcamp/monai/nvidia_monai_worksop_1/lab_4_Brain_Tumor_Segmentation_3D/model.pt
# Tue Nov 11 13:24:33 2025 Epoch: 1
# Epoch 1/5 0/80 loss: 0.8141 time 3.12s
# Epoch 1/5 1/80 loss: 0.8898 time 0.62s
# Epoch 1/5 2/80 loss: 0.8753 time 0.62s
# Epoch 1/5 3/80 loss: 0.9053 time 0.62s
# Epoch 1/5 4/80 loss: 0.8726 time 0.62s
# Epoch 1/5 5/80 loss: 0.8825 time 0.63s
# Epoch 1/5 6/80 loss: 0.8685 time 0.63s
# Epoch 1/5 7/80 loss: 0.8775 time 0.62s
# Epoch 1/5 8/80 loss: 0.8726 time 0.62s
# Epoch 1/5 9/80 loss: 0.8654 time 0.62s
# Epoch 1/5 10/80 loss: 0.8672 time 0.63s
# Epoch 1/5 11/80 loss: 0.8647 time 0.62s
# Epoch 1/5 12/80 loss: 0.8679 time 0.62s
# Epoch 1/5 13/80 loss: 0.8771 time 0.62s
# Epoch 1/5 14/80 loss: 0.8786 time 0.62s
# Epoch 1/5 15/80 loss: 0.8839 time 0.62s
# Epoch 1/5 16/80 loss: 0.8906 time 0.62s
# Epoch 1/5 17/80 loss: 0.8843 time 0.62s
# Epoch 1/5 18/80 loss: 0.8877 time 0.62s
# Epoch 1/5 19/80 loss: 0.8837 time 0.62s
# Epoch 1/5 20/80 loss: 0.8876 time 0.62s
# Epoch 1/5 21/80 loss: 0.8878 time 0.62s
# Epoch 1/5 22/80 loss: 0.8833 time 0.62s
# Epoch 1/5 23/80 loss: 0.8821 time 0.62s
# Epoch 1/5 24/80 loss: 0.8831 time 0.62s
# Epoch 1/5 25/80 loss: 0.8809 time 0.62s
# Epoch 1/5 26/80 loss: 0.8787 time 0.62s
# Epoch 1/5 27/80 loss: 0.8729 time 0.62s
# Epoch 1/5 28/80 loss: 0.8760 time 0.62s
# Epoch 1/5 29/80 loss: 0.8753 time 0.62s
# Epoch 1/5 30/80 loss: 0.8780 time 0.62s
# Epoch 1/5 31/80 loss: 0.8776 time 0.62s
# Epoch 1/5 32/80 loss: 0.8776 time 0.62s
# Epoch 1/5 33/80 loss: 0.8747 time 0.62s
# Epoch 1/5 34/80 loss: 0.8694 time 0.62s
# Epoch 1/5 35/80 loss: 0.8710 time 0.62s
# Epoch 1/5 36/80 loss: 0.8722 time 0.62s
# Epoch 1/5 37/80 loss: 0.8692 time 0.62s
# Epoch 1/5 38/80 loss: 0.8674 time 0.62s
# Epoch 1/5 39/80 loss: 0.8637 time 0.62s
# Epoch 1/5 40/80 loss: 0.8635 time 0.62s
# Epoch 1/5 41/80 loss: 0.8617 time 0.62s
# Epoch 1/5 42/80 loss: 0.8625 time 0.62s
# Epoch 1/5 43/80 loss: 0.8606 time 0.62s
# Epoch 1/5 44/80 loss: 0.8622 time 0.62s
# Epoch 1/5 45/80 loss: 0.8583 time 0.62s
# Epoch 1/5 46/80 loss: 0.8578 time 0.62s
# Epoch 1/5 47/80 loss: 0.8590 time 0.62s
# Epoch 1/5 48/80 loss: 0.8579 time 0.62s
# Epoch 1/5 49/80 loss: 0.8576 time 0.62s
# Epoch 1/5 50/80 loss: 0.8541 time 0.62s
# Epoch 1/5 51/80 loss: 0.8541 time 0.62s
# Epoch 1/5 52/80 loss: 0.8549 time 0.62s
# Epoch 1/5 53/80 loss: 0.8561 time 0.62s
# Epoch 1/5 54/80 loss: 0.8525 time 0.62s
# Epoch 1/5 55/80 loss: 0.8520 time 0.62s
# Epoch 1/5 56/80 loss: 0.8506 time 0.62s
# Epoch 1/5 57/80 loss: 0.8518 time 0.62s
# Epoch 1/5 58/80 loss: 0.8503 time 0.62s
# Epoch 1/5 59/80 loss: 0.8518 time 0.62s
# Epoch 1/5 60/80 loss: 0.8512 time 0.62s
# Epoch 1/5 61/80 loss: 0.8498 time 0.62s
# Epoch 1/5 62/80 loss: 0.8494 time 0.62s
# Epoch 1/5 63/80 loss: 0.8518 time 0.62s
# Epoch 1/5 64/80 loss: 0.8515 time 0.62s
# Epoch 1/5 65/80 loss: 0.8528 time 0.62s
# Epoch 1/5 66/80 loss: 0.8536 time 0.62s
# Epoch 1/5 67/80 loss: 0.8519 time 0.62s
# Epoch 1/5 68/80 loss: 0.8518 time 0.62s
# Epoch 1/5 69/80 loss: 0.8520 time 0.62s
# Epoch 1/5 70/80 loss: 0.8499 time 0.62s
# Epoch 1/5 71/80 loss: 0.8501 time 0.62s
# Epoch 1/5 72/80 loss: 0.8466 time 0.62s
# Epoch 1/5 73/80 loss: 0.8477 time 0.62s
# Epoch 1/5 74/80 loss: 0.8481 time 0.62s
# Epoch 1/5 75/80 loss: 0.8482 time 0.62s
# Epoch 1/5 76/80 loss: 0.8472 time 0.62s
# Epoch 1/5 77/80 loss: 0.8469 time 0.62s
# Epoch 1/5 78/80 loss: 0.8460 time 0.62s
# Epoch 1/5 79/80 loss: 0.8449 time 0.62s
# Final training  1/4 loss: 0.8449 time 52.31s
# Val 1/5 0/40 , dice_tc: 0.0362826 , dice_wt: 0.26338488 , dice_et: 0.028494857 , time 3.70s
# Val 1/5 1/40 , dice_tc: 0.13655797 , dice_wt: 0.32378444 , dice_et: 0.07768607 , time 1.53s
# Val 1/5 2/40 , dice_tc: 0.11957074 , dice_wt: 0.28565076 , dice_et: 0.07187631 , time 1.53s
# Val 1/5 3/40 , dice_tc: 0.14879322 , dice_wt: 0.28682843 , dice_et: 0.098259866 , time 1.53s
# Val 1/5 4/40 , dice_tc: 0.12614013 , dice_wt: 0.24207404 , dice_et: 0.08547725 , time 1.53s
# Val 1/5 5/40 , dice_tc: 0.12525678 , dice_wt: 0.24108076 , dice_et: 0.08453653 , time 1.53s
# Val 1/5 6/40 , dice_tc: 0.10801941 , dice_wt: 0.21376786 , dice_et: 0.07305438 , time 1.53s
# Val 1/5 7/40 , dice_tc: 0.095794536 , dice_wt: 0.2054817 , dice_et: 0.065341875 , time 1.53s
# Val 1/5 8/40 , dice_tc: 0.10751469 , dice_wt: 0.21226019 , dice_et: 0.08416316 , time 1.53s
# Val 1/5 9/40 , dice_tc: 0.09891082 , dice_wt: 0.21248057 , dice_et: 0.077817276 , time 1.53s
# Val 1/5 10/40 , dice_tc: 0.09913519 , dice_wt: 0.20754732 , dice_et: 0.07172887 , time 1.53s
# Val 1/5 11/40 , dice_tc: 0.09179074 , dice_wt: 0.19337 , dice_et: 0.066635676 , time 1.53s
# Val 1/5 12/40 , dice_tc: 0.0868001 , dice_wt: 0.18722096 , dice_et: 0.06326703 , time 1.53s
# Val 1/5 13/40 , dice_tc: 0.08302858 , dice_wt: 0.1921668 , dice_et: 0.0606079 , time 1.53s
# Val 1/5 14/40 , dice_tc: 0.08281905 , dice_wt: 0.19423348 , dice_et: 0.06184858 , time 1.53s
# Val 1/5 15/40 , dice_tc: 0.07858203 , dice_wt: 0.18726198 , dice_et: 0.058993198 , time 1.53s
# Val 1/5 16/40 , dice_tc: 0.088070355 , dice_wt: 0.19684827 , dice_et: 0.065782495 , time 1.53s
# Val 1/5 17/40 , dice_tc: 0.08536118 , dice_wt: 0.19676751 , dice_et: 0.06467392 , time 1.53s
# Val 1/5 18/40 , dice_tc: 0.08791267 , dice_wt: 0.1972822 , dice_et: 0.06500679 , time 1.53s
# Val 1/5 19/40 , dice_tc: 0.090633005 , dice_wt: 0.20300491 , dice_et: 0.06843131 , time 1.53s
# Val 1/5 20/40 , dice_tc: 0.09033069 , dice_wt: 0.20381519 , dice_et: 0.06843131 , time 1.53s
# Val 1/5 21/40 , dice_tc: 0.092899196 , dice_wt: 0.2054581 , dice_et: 0.07167927 , time 1.53s
# Val 1/5 22/40 , dice_tc: 0.09489872 , dice_wt: 0.21360365 , dice_et: 0.07302829 , time 1.53s
# Val 1/5 23/40 , dice_tc: 0.09274144 , dice_wt: 0.20928477 , dice_et: 0.07172034 , time 1.53s
# Val 1/5 24/40 , dice_tc: 0.093799315 , dice_wt: 0.2214876 , dice_et: 0.073473684 , time 1.53s
# Val 1/5 25/40 , dice_tc: 0.09754445 , dice_wt: 0.22700773 , dice_et: 0.0768363 , time 1.53s
# Val 1/5 26/40 , dice_tc: 0.095502906 , dice_wt: 0.22275609 , dice_et: 0.07524854 , time 1.53s
# Val 1/5 27/40 , dice_tc: 0.09234441 , dice_wt: 0.21544752 , dice_et: 0.07274913 , time 1.53s
# Val 1/5 28/40 , dice_tc: 0.09211614 , dice_wt: 0.22929028 , dice_et: 0.07259252 , time 1.53s
# Val 1/5 29/40 , dice_tc: 0.09196728 , dice_wt: 0.22812214 , dice_et: 0.072985396 , time 1.53s
# Val 1/5 30/40 , dice_tc: 0.09899238 , dice_wt: 0.23232058 , dice_et: 0.07746056 , time 1.53s
# Val 1/5 31/40 , dice_tc: 0.098815896 , dice_wt: 0.23350082 , dice_et: 0.07642362 , time 1.53s
# Val 1/5 32/40 , dice_tc: 0.09588035 , dice_wt: 0.22954622 , dice_et: 0.074096344 , time 1.53s
# Val 1/5 33/40 , dice_tc: 0.09550778 , dice_wt: 0.22845246 , dice_et: 0.07399946 , time 1.53s
# Val 1/5 34/40 , dice_tc: 0.10057157 , dice_wt: 0.23424843 , dice_et: 0.076741755 , time 1.53s
# Val 1/5 35/40 , dice_tc: 0.10152853 , dice_wt: 0.23971063 , dice_et: 0.07834851 , time 1.53s
# Val 1/5 36/40 , dice_tc: 0.10193193 , dice_wt: 0.2453988 , dice_et: 0.07917669 , time 1.53s
# Val 1/5 37/40 , dice_tc: 0.10026507 , dice_wt: 0.24286926 , dice_et: 0.07805905 , time 1.53s
# Val 1/5 38/40 , dice_tc: 0.09772697 , dice_wt: 0.23784623 , dice_et: 0.07601217 , time 1.53s
# Val 1/5 39/40 , dice_tc: 0.10095946 , dice_wt: 0.24265985 , dice_et: 0.077675454 , time 1.53s
# Final validation stats 1/4 , dice_tc: 0.10095946 , dice_wt: 0.24265985 , dice_et: 0.077675454 , Dice_Avg: 0.1404316 , time 63.45s
# Tue Nov 11 13:26:29 2025 Epoch: 2
# Epoch 2/5 0/80 loss: 0.8830 time 3.53s
# Epoch 2/5 1/80 loss: 0.8570 time 0.62s
# Epoch 2/5 2/80 loss: 0.8521 time 0.70s
# Epoch 2/5 3/80 loss: 0.8605 time 0.72s
# Epoch 2/5 4/80 loss: 0.8522 time 0.62s
# Epoch 2/5 5/80 loss: 0.8251 time 0.66s
# Epoch 2/5 6/80 loss: 0.8051 time 0.99s
# Epoch 2/5 7/80 loss: 0.8253 time 0.62s
# Epoch 2/5 8/80 loss: 0.8415 time 0.63s
# Epoch 2/5 9/80 loss: 0.8256 time 0.62s
# Epoch 2/5 10/80 loss: 0.8298 time 0.63s
# Epoch 2/5 11/80 loss: 0.8303 time 0.62s
# Epoch 2/5 12/80 loss: 0.8254 time 0.62s
# Epoch 2/5 13/80 loss: 0.8235 time 0.62s
# Epoch 2/5 14/80 loss: 0.8226 time 0.62s
# Epoch 2/5 15/80 loss: 0.8263 time 0.62s
# Epoch 2/5 16/80 loss: 0.8256 time 0.62s
# Epoch 2/5 17/80 loss: 0.8352 time 0.62s
# Epoch 2/5 18/80 loss: 0.8424 time 0.62s
# Epoch 2/5 19/80 loss: 0.8446 time 0.62s
# Epoch 2/5 20/80 loss: 0.8334 time 0.62s
# Epoch 2/5 21/80 loss: 0.8301 time 0.62s
# Epoch 2/5 22/80 loss: 0.8278 time 0.62s
# Epoch 2/5 23/80 loss: 0.8308 time 0.62s
# Epoch 2/5 24/80 loss: 0.8287 time 0.62s
# Epoch 2/5 25/80 loss: 0.8313 time 0.62s
# Epoch 2/5 26/80 loss: 0.8353 time 0.62s
# Epoch 2/5 27/80 loss: 0.8385 time 0.62s
# Epoch 2/5 28/80 loss: 0.8336 time 0.62s
# Epoch 2/5 29/80 loss: 0.8338 time 0.62s
# Epoch 2/5 30/80 loss: 0.8341 time 0.62s
# Epoch 2/5 31/80 loss: 0.8336 time 0.62s
# Epoch 2/5 32/80 loss: 0.8349 time 0.62s
# Epoch 2/5 33/80 loss: 0.8364 time 0.62s
# Epoch 2/5 34/80 loss: 0.8308 time 0.62s
# Epoch 2/5 35/80 loss: 0.8248 time 0.62s
# Epoch 2/5 36/80 loss: 0.8244 time 0.62s
# Epoch 2/5 37/80 loss: 0.8214 time 0.62s
# Epoch 2/5 38/80 loss: 0.8169 time 0.62s
# Epoch 2/5 39/80 loss: 0.8146 time 0.62s
# Epoch 2/5 40/80 loss: 0.8165 time 0.62s
# Epoch 2/5 41/80 loss: 0.8186 time 0.62s
# Epoch 2/5 42/80 loss: 0.8200 time 0.62s
# Epoch 2/5 43/80 loss: 0.8187 time 0.62s
# Epoch 2/5 44/80 loss: 0.8193 time 0.62s
# Epoch 2/5 45/80 loss: 0.8177 time 0.62s
# Epoch 2/5 46/80 loss: 0.8206 time 0.62s
# Epoch 2/5 47/80 loss: 0.8195 time 0.62s
# Epoch 2/5 48/80 loss: 0.8164 time 0.62s
# Epoch 2/5 49/80 loss: 0.8145 time 0.62s
# Epoch 2/5 50/80 loss: 0.8115 time 0.62s
# Epoch 2/5 51/80 loss: 0.8125 time 0.62s
# Epoch 2/5 52/80 loss: 0.8079 time 0.62s
# Epoch 2/5 53/80 loss: 0.8107 time 0.62s
# Epoch 2/5 54/80 loss: 0.8096 time 0.62s
# Epoch 2/5 55/80 loss: 0.8094 time 0.62s
# Epoch 2/5 56/80 loss: 0.8112 time 0.62s
# Epoch 2/5 57/80 loss: 0.8127 time 0.62s
# Epoch 2/5 58/80 loss: 0.8121 time 0.62s
# Epoch 2/5 59/80 loss: 0.8134 time 0.62s
# Epoch 2/5 60/80 loss: 0.8116 time 0.62s
# Epoch 2/5 61/80 loss: 0.8127 time 0.62s
# Epoch 2/5 62/80 loss: 0.8136 time 0.62s
# Epoch 2/5 63/80 loss: 0.8117 time 0.62s
# Epoch 2/5 64/80 loss: 0.8118 time 0.62s
# Epoch 2/5 65/80 loss: 0.8142 time 0.62s
# Epoch 2/5 66/80 loss: 0.8148 time 0.62s
# Epoch 2/5 67/80 loss: 0.8144 time 0.62s
# Epoch 2/5 68/80 loss: 0.8141 time 0.62s
# Epoch 2/5 69/80 loss: 0.8122 time 0.62s
# Epoch 2/5 70/80 loss: 0.8124 time 0.62s
# Epoch 2/5 71/80 loss: 0.8143 time 0.62s
# Epoch 2/5 72/80 loss: 0.8144 time 0.62s
# Epoch 2/5 73/80 loss: 0.8125 time 0.62s
# Epoch 2/5 74/80 loss: 0.8124 time 0.62s
# Epoch 2/5 75/80 loss: 0.8109 time 0.62s
# Epoch 2/5 76/80 loss: 0.8119 time 0.62s
# Epoch 2/5 77/80 loss: 0.8132 time 0.62s
# Epoch 2/5 78/80 loss: 0.8155 time 0.62s
# Epoch 2/5 79/80 loss: 0.8158 time 0.62s
# Final training  2/4 loss: 0.8158 time 53.26s
# Tue Nov 11 13:27:22 2025 Epoch: 3
# Epoch 3/5 0/80 loss: 1.0000 time 3.37s
# Epoch 3/5 1/80 loss: 0.9356 time 0.62s
# Epoch 3/5 2/80 loss: 0.9068 time 0.62s
# Epoch 3/5 3/80 loss: 0.8509 time 0.62s
# Epoch 3/5 4/80 loss: 0.8444 time 0.62s
# Epoch 3/5 5/80 loss: 0.8350 time 0.62s
# Epoch 3/5 6/80 loss: 0.8065 time 0.62s
# Epoch 3/5 7/80 loss: 0.8147 time 0.62s
# Epoch 3/5 8/80 loss: 0.8326 time 0.62s
# Epoch 3/5 9/80 loss: 0.8392 time 0.62s
# Epoch 3/5 10/80 loss: 0.8265 time 0.62s
# Epoch 3/5 11/80 loss: 0.8338 time 0.62s
# Epoch 3/5 12/80 loss: 0.8212 time 0.62s
# Epoch 3/5 13/80 loss: 0.8186 time 0.62s
# Epoch 3/5 14/80 loss: 0.8187 time 0.62s
# Epoch 3/5 15/80 loss: 0.8252 time 0.62s
# Epoch 3/5 16/80 loss: 0.8352 time 0.62s
# Epoch 3/5 17/80 loss: 0.8306 time 0.62s
# Epoch 3/5 18/80 loss: 0.8364 time 0.62s
# Epoch 3/5 19/80 loss: 0.8394 time 0.62s
# Epoch 3/5 20/80 loss: 0.8404 time 0.62s
# Epoch 3/5 21/80 loss: 0.8412 time 0.62s
# Epoch 3/5 22/80 loss: 0.8316 time 0.62s
# Epoch 3/5 23/80 loss: 0.8306 time 0.62s
# Epoch 3/5 24/80 loss: 0.8300 time 0.62s
# Epoch 3/5 25/80 loss: 0.8315 time 0.62s
# Epoch 3/5 26/80 loss: 0.8305 time 0.62s
# Epoch 3/5 27/80 loss: 0.8260 time 0.62s
# Epoch 3/5 28/80 loss: 0.8293 time 0.62s
# Epoch 3/5 29/80 loss: 0.8324 time 0.62s
# Epoch 3/5 30/80 loss: 0.8299 time 0.62s
# Epoch 3/5 31/80 loss: 0.8334 time 0.62s
# Epoch 3/5 32/80 loss: 0.8384 time 0.62s
# Epoch 3/5 33/80 loss: 0.8426 time 0.62s
# Epoch 3/5 34/80 loss: 0.8408 time 0.62s
# Epoch 3/5 35/80 loss: 0.8415 time 0.62s
# Epoch 3/5 36/80 loss: 0.8407 time 0.62s
# Epoch 3/5 37/80 loss: 0.8390 time 0.62s
# Epoch 3/5 38/80 loss: 0.8396 time 0.62s
# Epoch 3/5 39/80 loss: 0.8358 time 0.62s
# Epoch 3/5 40/80 loss: 0.8395 time 0.62s
# Epoch 3/5 41/80 loss: 0.8364 time 0.62s
# Epoch 3/5 42/80 loss: 0.8402 time 0.62s
# Epoch 3/5 43/80 loss: 0.8381 time 0.62s
# Epoch 3/5 44/80 loss: 0.8351 time 0.62s
# Epoch 3/5 45/80 loss: 0.8347 time 0.62s
# Epoch 3/5 46/80 loss: 0.8358 time 0.62s
# Epoch 3/5 47/80 loss: 0.8361 time 0.62s
# Epoch 3/5 48/80 loss: 0.8349 time 0.62s
# Epoch 3/5 49/80 loss: 0.8296 time 0.62s
# Epoch 3/5 50/80 loss: 0.8279 time 0.62s
# Epoch 3/5 51/80 loss: 0.8231 time 0.62s
# Epoch 3/5 52/80 loss: 0.8261 time 0.62s
# Epoch 3/5 53/80 loss: 0.8263 time 0.62s
# Epoch 3/5 54/80 loss: 0.8244 time 0.62s
# Epoch 3/5 55/80 loss: 0.8268 time 0.62s
# Epoch 3/5 56/80 loss: 0.8278 time 0.62s
# Epoch 3/5 57/80 loss: 0.8242 time 0.62s
# Epoch 3/5 58/80 loss: 0.8243 time 0.62s
# Epoch 3/5 59/80 loss: 0.8250 time 0.62s
# Epoch 3/5 60/80 loss: 0.8229 time 0.62s
# Epoch 3/5 61/80 loss: 0.8210 time 0.62s
# Epoch 3/5 62/80 loss: 0.8194 time 0.62s
# Epoch 3/5 63/80 loss: 0.8222 time 0.62s
# Epoch 3/5 64/80 loss: 0.8204 time 0.62s
# Epoch 3/5 65/80 loss: 0.8211 time 0.62s
# Epoch 3/5 66/80 loss: 0.8196 time 0.62s
# Epoch 3/5 67/80 loss: 0.8221 time 0.62s
# Epoch 3/5 68/80 loss: 0.8241 time 0.62s
# Epoch 3/5 69/80 loss: 0.8217 time 0.62s
# Epoch 3/5 70/80 loss: 0.8228 time 0.62s
# Epoch 3/5 71/80 loss: 0.8225 time 0.62s
# Epoch 3/5 72/80 loss: 0.8217 time 0.62s
# Epoch 3/5 73/80 loss: 0.8198 time 0.62s
# Epoch 3/5 74/80 loss: 0.8220 time 0.62s
# Epoch 3/5 75/80 loss: 0.8192 time 0.62s
# Epoch 3/5 76/80 loss: 0.8210 time 0.62s
# Epoch 3/5 77/80 loss: 0.8184 time 0.62s
# Epoch 3/5 78/80 loss: 0.8186 time 0.62s
# Epoch 3/5 79/80 loss: 0.8173 time 0.62s
# Final training  3/4 loss: 0.8173 time 52.47s
# Val 3/5 0/40 , dice_tc: 0.04317274 , dice_wt: 0.32073516 , dice_et: 0.033659514 , time 3.72s
# Val 3/5 1/40 , dice_tc: 0.14823733 , dice_wt: 0.3650793 , dice_et: 0.08302306 , time 1.53s
# Val 3/5 2/40 , dice_tc: 0.13171868 , dice_wt: 0.32619497 , dice_et: 0.07958548 , time 1.53s
# Val 3/5 3/40 , dice_tc: 0.16769207 , dice_wt: 0.3356087 , dice_et: 0.11491719 , time 1.53s
# Val 3/5 4/40 , dice_tc: 0.13747987 , dice_wt: 0.27484623 , dice_et: 0.09555586 , time 1.53s
# Val 3/5 5/40 , dice_tc: 0.13774498 , dice_wt: 0.27600652 , dice_et: 0.09593433 , time 1.53s
# Val 3/5 6/40 , dice_tc: 0.118838966 , dice_wt: 0.2449441 , dice_et: 0.082924485 , time 1.53s
# Val 3/5 7/40 , dice_tc: 0.105356395 , dice_wt: 0.23514654 , dice_et: 0.07414848 , time 1.53s
# Val 3/5 8/40 , dice_tc: 0.115283795 , dice_wt: 0.23796743 , dice_et: 0.09277201 , time 1.53s
# Val 3/5 9/40 , dice_tc: 0.10596738 , dice_wt: 0.23765793 , dice_et: 0.085666336 , time 1.53s
# Val 3/5 10/40 , dice_tc: 0.106829375 , dice_wt: 0.2322402 , dice_et: 0.078925095 , time 1.53s
# Val 3/5 11/40 , dice_tc: 0.09877491 , dice_wt: 0.21591593 , dice_et: 0.07319075 , time 1.53s
# Val 3/5 12/40 , dice_tc: 0.093105644 , dice_wt: 0.20793301 , dice_et: 0.06922295 , time 1.53s
# Val 3/5 13/40 , dice_tc: 0.089215934 , dice_wt: 0.21468832 , dice_et: 0.06647971 , time 1.53s
# Val 3/5 14/40 , dice_tc: 0.089519 , dice_wt: 0.21890825 , dice_et: 0.06861543 , time 1.53s
# Val 3/5 15/40 , dice_tc: 0.08492823 , dice_wt: 0.21095091 , dice_et: 0.06543422 , time 1.53s
# Val 3/5 16/40 , dice_tc: 0.09424865 , dice_wt: 0.22032095 , dice_et: 0.07191591 , time 1.53s
# Val 3/5 17/40 , dice_tc: 0.09133844 , dice_wt: 0.21993308 , dice_et: 0.070640504 , time 1.53s
# Val 3/5 18/40 , dice_tc: 0.093783356 , dice_wt: 0.22019272 , dice_et: 0.07086291 , time 1.53s
# Val 3/5 19/40 , dice_tc: 0.096056916 , dice_wt: 0.2249072 , dice_et: 0.07397036 , time 1.53s
# Val 3/5 20/40 , dice_tc: 0.09647368 , dice_wt: 0.22638547 , dice_et: 0.07397036 , time 1.53s
# Val 3/5 21/40 , dice_tc: 0.09855227 , dice_wt: 0.22718109 , dice_et: 0.0768318 , time 1.53s
# Val 3/5 22/40 , dice_tc: 0.10198612 , dice_wt: 0.23951966 , dice_et: 0.0796492 , time 1.53s
# Val 3/5 23/40 , dice_tc: 0.09946748 , dice_wt: 0.23415215 , dice_et: 0.07798035 , time 1.53s
# Val 3/5 24/40 , dice_tc: 0.100258 , dice_wt: 0.24547793 , dice_et: 0.07964939 , time 1.53s
# Val 3/5 25/40 , dice_tc: 0.10517432 , dice_wt: 0.25324762 , dice_et: 0.08444456 , time 1.53s
# Val 3/5 26/40 , dice_tc: 0.10324641 , dice_wt: 0.2493531 , dice_et: 0.08292605 , time 1.53s
# Val 3/5 27/40 , dice_tc: 0.099729694 , dice_wt: 0.240903 , dice_et: 0.08007299 , time 1.53s
# Val 3/5 28/40 , dice_tc: 0.09807977 , dice_wt: 0.24749623 , dice_et: 0.07875515 , time 1.53s
# Val 3/5 29/40 , dice_tc: 0.09777335 , dice_wt: 0.24608438 , dice_et: 0.07904876 , time 1.53s
# Val 3/5 30/40 , dice_tc: 0.104078345 , dice_wt: 0.24959141 , dice_et: 0.08319559 , time 1.53s
# Val 3/5 31/40 , dice_tc: 0.10486749 , dice_wt: 0.25390738 , dice_et: 0.08268247 , time 1.53s
# Val 3/5 32/40 , dice_tc: 0.1017426 , dice_wt: 0.24912149 , dice_et: 0.08015922 , time 1.53s
# Val 3/5 33/40 , dice_tc: 0.101668224 , dice_wt: 0.24853726 , dice_et: 0.080389574 , time 1.53s
# Val 3/5 34/40 , dice_tc: 0.106126174 , dice_wt: 0.2533823 , dice_et: 0.0825841 , time 1.53s
# Val 3/5 35/40 , dice_tc: 0.10813622 , dice_wt: 0.2612968 , dice_et: 0.08506027 , time 1.53s
# Val 3/5 36/40 , dice_tc: 0.10835579 , dice_wt: 0.26700446 , dice_et: 0.08580033 , time 1.53s
# Val 3/5 37/40 , dice_tc: 0.10641837 , dice_wt: 0.26374668 , dice_et: 0.08444817 , time 1.53s
# Val 3/5 38/40 , dice_tc: 0.1037235 , dice_wt: 0.25825998 , dice_et: 0.08223377 , time 1.53s
# Val 3/5 39/40 , dice_tc: 0.10788242 , dice_wt: 0.26493198 , dice_et: 0.08473313 , time 1.53s
# Final validation stats 3/4 , dice_tc: 0.10788242 , dice_wt: 0.26493198 , dice_et: 0.08473313 , Dice_Avg: 0.15251584 , time 63.44s
# Tue Nov 11 13:29:18 2025 Epoch: 4
# Epoch 4/5 0/80 loss: 0.7171 time 3.09s
# Epoch 4/5 1/80 loss: 0.7910 time 0.62s
# Epoch 4/5 2/80 loss: 0.7739 time 0.66s
# Epoch 4/5 3/80 loss: 0.7152 time 0.66s
# Epoch 4/5 4/80 loss: 0.6933 time 0.62s
# Epoch 4/5 5/80 loss: 0.7168 time 0.62s
# Epoch 4/5 6/80 loss: 0.7491 time 0.62s
# Epoch 4/5 7/80 loss: 0.7522 time 0.62s
# Epoch 4/5 8/80 loss: 0.7585 time 0.62s
# Epoch 4/5 9/80 loss: 0.7772 time 0.62s
# Epoch 4/5 10/80 loss: 0.7804 time 0.62s
# Epoch 4/5 11/80 loss: 0.7753 time 0.62s
# Epoch 4/5 12/80 loss: 0.7910 time 0.62s
# Epoch 4/5 13/80 loss: 0.7939 time 0.62s
# Epoch 4/5 14/80 loss: 0.7852 time 0.62s
# Epoch 4/5 15/80 loss: 0.7942 time 0.62s
# Epoch 4/5 16/80 loss: 0.7911 time 0.64s
# Epoch 4/5 17/80 loss: 0.7874 time 0.62s
# Epoch 4/5 18/80 loss: 0.7888 time 0.62s
# Epoch 4/5 19/80 loss: 0.7927 time 0.62s
# Epoch 4/5 20/80 loss: 0.7937 time 0.62s
# Epoch 4/5 21/80 loss: 0.7989 time 0.62s
# Epoch 4/5 22/80 loss: 0.7982 time 0.62s
# Epoch 4/5 23/80 loss: 0.8024 time 0.62s
# Epoch 4/5 24/80 loss: 0.8022 time 0.62s
# Epoch 4/5 25/80 loss: 0.7994 time 0.62s
# Epoch 4/5 26/80 loss: 0.7985 time 0.62s
# Epoch 4/5 27/80 loss: 0.7975 time 0.62s
# Epoch 4/5 28/80 loss: 0.8045 time 0.62s
# Epoch 4/5 29/80 loss: 0.7965 time 0.62s
# Epoch 4/5 30/80 loss: 0.7982 time 0.62s
# Epoch 4/5 31/80 loss: 0.8034 time 0.62s
# Epoch 4/5 32/80 loss: 0.8088 time 0.62s
# Epoch 4/5 33/80 loss: 0.8075 time 0.63s
# Epoch 4/5 34/80 loss: 0.8051 time 0.85s
# Epoch 4/5 35/80 loss: 0.8015 time 0.62s
# Epoch 4/5 36/80 loss: 0.7997 time 0.62s
# Epoch 4/5 37/80 loss: 0.8003 time 0.62s
# Epoch 4/5 38/80 loss: 0.8031 time 0.62s
# Epoch 4/5 39/80 loss: 0.8046 time 0.62s
# Epoch 4/5 40/80 loss: 0.8043 time 0.62s
# Epoch 4/5 41/80 loss: 0.7996 time 0.62s
# Epoch 4/5 42/80 loss: 0.8013 time 0.62s
# Epoch 4/5 43/80 loss: 0.7982 time 0.62s
# Epoch 4/5 44/80 loss: 0.8002 time 0.62s
# Epoch 4/5 45/80 loss: 0.7997 time 0.62s
# Epoch 4/5 46/80 loss: 0.8000 time 0.62s
# Epoch 4/5 47/80 loss: 0.8008 time 0.62s
# Epoch 4/5 48/80 loss: 0.8010 time 0.62s
# Epoch 4/5 49/80 loss: 0.8007 time 0.62s
# Epoch 4/5 50/80 loss: 0.8006 time 0.62s
# Epoch 4/5 51/80 loss: 0.7999 time 0.62s
# Epoch 4/5 52/80 loss: 0.8013 time 0.62s
# Epoch 4/5 53/80 loss: 0.8005 time 0.62s
# Epoch 4/5 54/80 loss: 0.8037 time 0.62s
# Epoch 4/5 55/80 loss: 0.7981 time 0.62s
# Epoch 4/5 56/80 loss: 0.7977 time 0.63s
# Epoch 4/5 57/80 loss: 0.7984 time 0.62s
# Epoch 4/5 58/80 loss: 0.7979 time 0.62s
# Epoch 4/5 59/80 loss: 0.7981 time 0.62s
# Epoch 4/5 60/80 loss: 0.7996 time 0.62s
# Epoch 4/5 61/80 loss: 0.7971 time 0.62s
# Epoch 4/5 62/80 loss: 0.7967 time 0.63s
# Epoch 4/5 63/80 loss: 0.7960 time 0.62s
# Epoch 4/5 64/80 loss: 0.7978 time 0.62s
# Epoch 4/5 65/80 loss: 0.7975 time 0.62s
# Epoch 4/5 66/80 loss: 0.8003 time 0.62s
# Epoch 4/5 67/80 loss: 0.8005 time 0.62s
# Epoch 4/5 68/80 loss: 0.8030 time 0.62s
# Epoch 4/5 69/80 loss: 0.8008 time 0.62s
# Epoch 4/5 70/80 loss: 0.7999 time 0.62s
# Epoch 4/5 71/80 loss: 0.7990 time 0.62s
# Epoch 4/5 72/80 loss: 0.7986 time 0.62s
# Epoch 4/5 73/80 loss: 0.7972 time 0.62s
# Epoch 4/5 74/80 loss: 0.7984 time 0.62s
# Epoch 4/5 75/80 loss: 0.8000 time 0.62s
# Epoch 4/5 76/80 loss: 0.8005 time 0.62s
# Epoch 4/5 77/80 loss: 0.8008 time 0.62s
# Epoch 4/5 78/80 loss: 0.8005 time 0.62s
# Epoch 4/5 79/80 loss: 0.7990 time 0.62s
# Final training  4/4 loss: 0.7990 time 52.54s
# Training Finished !, Best Accuracy:  0.17132676

# %%
print(f"train completed, best average dice: {val_acc_max:.4f} ")

# Close the SummaryWriter
writer.close()
# Out:
# train completed, best average dice: 0.1713

# %% [markdown]
# ## Tensorboard to show the training loss and validation loss

# %%
## Port num preparation

username = !whoami
username = username[-1]

if username != 'qmedasia':
    tb_portnum = 8700+int(username[-1][-2:])
else:
    tb_portnum = 8789

# %%
# %%capture
#%reload_ext tensorboard
# %load_ext tensorboard
# %tensorboard --logdir runs --host 0.0.0.0 --port $tb_portnum

# %%
# %%capture captured_cell
# %%bash
ifconfig enp226s0 | grep -Po '(?<=inet )(\d{1,3}\.){3}\d{1,3}'

# %%
print("Visit IP address: http://%s:%d/  in the browser for the visualization of the tensorboard."% (captured_cell.stdout[:-1],tb_portnum))
# Out:
# Visit IP address: http://10.11.132.43:8789/  in the browser for the visualization of the tensorboard.

# %% [markdown]
# ## Stop Tensorboard (before moving to the next lab)

# %%
from tensorboard import notebook
notebook.list()
# Out:
# No known TensorBoard instances running.

# %%
# %%capture captured_cell

notebook.list()

# %%
pid_to_kill = captured_cell.stdout.split('\n')[1].split('pid ')[-1][:-1]
print('PID to kill: ',pid_to_kill)
# !kill $pid_to_kill
notebook.list()
# Out:
# PID to kill:  1918972
# /bin/bash: /app/miniconda/24.11.1/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# No known TensorBoard instances running.

# %% [markdown]
# ## Check Final VRAM Usage

# %%
final_vram = torch.cuda.max_memory_allocated()
print(f"Final Peak VRAM during training: {final_vram / 1024**2:.2f} MB")

print(f"Current VRAM: {torch.cuda.memory_allocated() / 1024**2:.2f} MB")

# !nvidia-smi
# Out:
# Final Peak VRAM during training: 24550.13 MB
# Current VRAM: 1264.22 MB
# /bin/bash: /app/miniconda/24.11.1/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Tue Nov 11 13:30:11 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.216.03             Driver Version: 535.216.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-80GB          On  | 00000000:07:00.0 Off |                   On |
# | N/A   38C    P0              78W / 400W |  11313MiB / 81920MiB |     N/A      Default |
# |                                         |                      |              Enabled |
# +-----------------------------------------+----------------------+----------------------+
# |   1  NVIDIA A100-SXM4-80GB          On  | 00000000:0F:00.0 Off |                   On |
# | N/A   42C    P0             173W / 400W |  29589MiB / 81920MiB |     N/A      Default |
# |                                         |                      |              Enabled |
# +-----------------------------------------+----------------------+----------------------+
# |   2  NVIDIA A100-SXM4-80GB          On  | 00000000:47:00.0 Off |                   On |
# | N/A   27C    P0              57W / 400W |  40237MiB / 81920MiB |     N/A      Default |
# |                                         |                      |              Enabled |
# +-----------------------------------------+----------------------+----------------------+
# |   3  NVIDIA A100-SXM4-80GB          On  | 00000000:4E:00.0 Off |                   On |
# | N/A   26C    P0              51W / 400W |     87MiB / 81920MiB |     N/A      Default |
# |                                         |                      |              Enabled |
# +-----------------------------------------+----------------------+----------------------+
# |   4  NVIDIA A100-SXM4-80GB          On  | 00000000:87:00.0 Off |                   On |
# | N/A   36C    P0              52W / 400W |     87MiB / 81920MiB |     N/A      Default |
# |                                         |                      |              Enabled |
# +-----------------------------------------+----------------------+----------------------+
# |   5  NVIDIA A100-SXM4-80GB          On  | 00000000:90:00.0 Off |                   On |
# | N/A   37C    P0              54W / 400W |     87MiB / 81920MiB |     N/A      Default |
# |                                         |                      |              Enabled |
# +-----------------------------------------+----------------------+----------------------+
# |   6  NVIDIA A100-SXM4-80GB          On  | 00000000:B7:00.0 Off |                   On |
# | N/A   29C    P0              51W / 400W |     87MiB / 81920MiB |     N/A      Default |
# |                                         |                      |              Enabled |
# +-----------------------------------------+----------------------+----------------------+
# |   7  NVIDIA A100-SXM4-80GB          On  | 00000000:BD:00.0 Off |                   On |
# | N/A   29C    P0              52W / 400W |     87MiB / 81920MiB |     N/A      Default |
# |                                         |                      |              Enabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | MIG devices:                                                                          |
# +------------------+--------------------------------+-----------+-----------------------+
# | GPU  GI  CI  MIG |                   Memory-Usage |        Vol|      Shared           |
# |      ID  ID  Dev |                     BAR1-Usage | SM     Unc| CE ENC DEC OFA JPG    |
# |                  |                                |        ECC|                       |
# |==================+================================+===========+=======================|
# |  0    2   0   0  |           11264MiB / 40192MiB  | 42      0 |  3   0    2    0    0 |
# |                  |               2MiB / 65535MiB  |           |                       |
# +------------------+--------------------------------+-----------+-----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0    2    0    1352443      C   ...qmedasia/monai_py311/bin/python3.11    11208MiB |
# |    1    2    0     147821      C   ...kun/.conda/envs/mamba310/bin/python    29494MiB |
# |    2    2    0    1365388      C   ...e/user/leokun/jupyterlab/bin/python    40142MiB |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ### Plot the loss and Dice metric

# %%
plt.figure("train", (12, 6))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
plt.xlabel("epoch")
plt.plot(trains_epoch, loss_epochs, color="red")
plt.subplot(1, 2, 2)
plt.title("Val Mean Dice")
plt.xlabel("epoch")
plt.plot(trains_epoch, dices_avg, color="green")
plt.show()
plt.figure("train", (18, 6))
plt.subplot(1, 3, 1)
plt.title("Val Mean Dice TC")
plt.xlabel("epoch")
plt.plot(trains_epoch, dices_tc, color="blue")
plt.subplot(1, 3, 2)
plt.title("Val Mean Dice WT")
plt.xlabel("epoch")
plt.plot(trains_epoch, dices_wt, color="brown")
plt.subplot(1, 3, 3)
plt.title("Val Mean Dice ET")
plt.xlabel("epoch")
plt.plot(trains_epoch, dices_et, color="purple")
plt.show()

# %% [markdown]
# ## Create test set dataloader

# %%
case_num = "01499"

test_files = [
    {
        "image": [
            os.path.join(
                data_dir,
                "TrainingData/BraTS2021_" + case_num + "/BraTS2021_" + case_num + "_flair.nii.gz",
            ),
            os.path.join(
                data_dir,
                "TrainingData/BraTS2021_" + case_num + "/BraTS2021_" + case_num + "_t1ce.nii.gz",
            ),
            os.path.join(
                data_dir,
                "TrainingData/BraTS2021_" + case_num + "/BraTS2021_" + case_num + "_t1.nii.gz",
            ),
            os.path.join(
                data_dir,
                "TrainingData/BraTS2021_" + case_num + "/BraTS2021_" + case_num + "_t2.nii.gz",
            ),
        ],
        "label": os.path.join(
            data_dir,
            "TrainingData/BraTS2021_" + case_num + "/BraTS2021_" + case_num + "_seg.nii.gz",
        ),
    }
]

test_transform = transforms.Compose(
    [
        transforms.LoadImaged(keys=["image", "label"]),
        transforms.ConvertToMultiChannelBasedOnBratsClassesd(keys="label"),
        transforms.NormalizeIntensityd(keys="image", nonzero=True, channel_wise=True),
    ]
)

test_ds = data.Dataset(data=test_files, transform=test_transform)

test_loader = data.DataLoader(
    test_ds,
    batch_size=1,
    shuffle=False,
    num_workers=8,
    pin_memory=True,
)

# %% [markdown]
# ## Load the best saved checkpoint and perform inference
#
# We select a single case from the validation set and perform inference to compare the model segmentation output with the corresponding label.

# %%
model.load_state_dict(torch.load(os.path.join(root_dir, "model.pt"), weights_only=False)["state_dict"])
model.to(device)
model.eval()

model_inferer_test = partial(
    sliding_window_inference,
    roi_size=[roi[0], roi[1], roi[2]],
    sw_batch_size=1,
    predictor=model,
    overlap=0.6,
)


with torch.no_grad():
    for batch_data in test_loader:
        image = batch_data["image"].cuda()
        prob = torch.sigmoid(model_inferer_test(image))
        seg = prob[0].detach().cpu().numpy()
        seg = (seg > 0.5).astype(np.int8)
        seg_out = np.zeros((seg.shape[1], seg.shape[2], seg.shape[3]))
        seg_out[seg[1] == 1] = 2
        seg_out[seg[0] == 1] = 1
        seg_out[seg[2] == 1] = 4

# %% [markdown]
# ## Visualize segmentation output and compare with label

# %%
slice_num = 67
img_add = os.path.join(
    data_dir,
    "TrainingData/BraTS2021_" + case_num + "/BraTS2021_" + case_num + "_t1ce.nii.gz",
)
label_add = os.path.join(
    data_dir,
    "TrainingData/BraTS2021_" + case_num + "/BraTS2021_" + case_num + "_seg.nii.gz",
)
img = nib.load(img_add).get_fdata()
label = nib.load(label_add).get_fdata()
plt.figure("image", (18, 6))
plt.subplot(1, 3, 1)
plt.title("image")
plt.imshow(img[:, :, slice_num], cmap="gray")
plt.subplot(1, 3, 2)
plt.title("label")
plt.imshow(label[:, :, slice_num])
plt.subplot(1, 3, 3)
plt.title("segmentation")
plt.imshow(seg_out[:, :, slice_num])
plt.show()
